# %%
import os
import sys
# On ajoute le dossier modeling au PYTHONPATH
sys.path.append(os.path.abspath("modeling"))

# On affiche les graphiques dans le notebook en statique
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import time

import cudf
import cuml
import os
import gc
import joblib

import mlflow
import cupy as cp

# from cuml import LogisticRegression as CuLogisticRegression
from cuml.pipeline import Pipeline as CuPipeline
from cuml.preprocessing import StandardScaler as CuStandardScaler
from cuml.preprocessing import SimpleImputer as CuSimpleImputer

from sklearn.model_selection import train_test_split as sk_train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

from sklearn.dummy import DummyClassifier
from lightgbm import LGBMClassifier
from imblearn.pipeline import Pipeline as ImblearnPipeline
from imblearn.over_sampling import SMOTE


from src.p7_util import format_time, save_pkl, read_pkl

import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
from src.constantes import (
    DATA_CLEAN_DIR,
    MODEL_DIR,
    VAL_SEED,
)

from src.p7_util import reduce_memory_cudf
from src.p7_evaluate import EvaluatorCV, Evaluator
from src.p7_importance import (
    importance_from_model,
    plot_line_importance,
    plot_bar_importances,
)
from src.p7_comparative_table import ComparativeTable
from src.p7_rfecv import RfecvSelector
from src.p7_tracking import start_mlflow_ui, create_or_load_experiment


from src.p7_tracking import merge_dicts_with_prefixes, pil_image_from_fig
from src.p7_tracking import log_features, log_scoring_params, log_image
from src.p7_util import read_train, read_pkl, save_pkl


# %load_ext autoreload
# %autoreload 2
#autoreload 2 = Reload all modules (except those excluded by %aimport)
# every time before executing the Python code typed.

# %%
pd.set_option("display.max_colwidth", 400)

# %%
print("cuDF version:", cudf.__version__)
print("cuML version:", cuml.__version__)
print("mlflow version:", mlflow.__version__)
# Out:
# cuDF version: 24.04.01
# cuML version: 24.04.00
# mlflow version: 2.13.0

# %% [markdown]
# ## Fonction codée pour ce notebook

# %%
def read_sample(
    name="01_v2_vif_sampled_train.csv",
    to_cpu=False,
    directory=DATA_CLEAN_DIR,
    verbose=True,
):
    sampled_train = cudf.read_csv(os.path.join(directory, name))
    if to_cpu:
        sampled_train = sampled_train.to_pandas()
    predictors = [f for f in sampled_train.columns if f not in ["SK_ID_CURR", "TARGET"]]
    X = sampled_train[predictors]
    y = sampled_train["TARGET"]
    if verbose:
        print("Info X :")
        print(X.info())
        print("\nInfo y :")
        print("Classe", y.__class__.__name__)
        print("Type", y.dtype)
        print("Shape", y.shape)
    return X, y

# %% [markdown]
# ## Lecture des données de train

# %%
train = cudf.read_csv(os.path.join(DATA_CLEAN_DIR, "01_v2_vif_train.csv"))
train.info()
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 230634 entries, 0 to 230633
# Columns: 426 entries, SK_ID_CURR to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(249), int64(31)
# memory usage: 532.2 MB

# %%
N_ROWS = train.shape[0]
print("Nombre de lignes dans la totalité du train :", N_ROWS)
# Out:
# Nombre de lignes dans la totalité du train : 230634

# %%
train = reduce_memory_cudf(train)
# Out:
# Memory usage of dataframe is 532.18 MB
# Memory usage after optimization is: 302.55 MB
# Decreased by 43.1%

# %%
predictors = [f for f in train.columns if f not in ["SK_ID_CURR", "TARGET"]]
X = train[predictors].to_pandas()
y = train["TARGET"].to_pandas()

# %% [markdown]
# # Echantillonnage

# %% [markdown]
# ## Réduction du nombre de lignes

# %% [markdown]
# ### Echantillon 30%

# %%
sampled_train, _ = sk_train_test_split(
    train.to_pandas(),
    test_size=0.7,
    stratify=train["TARGET"].to_pandas(),
    shuffle=True,
    random_state=VAL_SEED,
)
sampled_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69190 entries, 170245 to 38394
# Columns: 426 entries, SK_ID_CURR to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float32(242), float64(29), int32(7), int64(2)
# memory usage: 92.2 MB

# %% [markdown]
# ### Sauvegarde de l'échantillon

# %%
filepath = os.path.join(DATA_CLEAN_DIR, "01_v2_vif_sampled_train.csv")
sampled_train.to_csv(filepath, index=False)
print(f"Echantillon (30% des données) enregistré dans {filepath}")
# Out:
# Echantillon (30% des données) enregistré dans data/cleaned/01_v2_vif_sampled_train.csv

# %% [markdown]
# # Dummy classifier sur toutes les features

# %%
X, y = read_sample(to_cpu=True)
n_features = len(X.columns)
print()

model = DummyClassifier(strategy="most_frequent")
evaluator0 = EvaluatorCV(pipe=model, device="CPU", cv=5, random_state=VAL_SEED)
_ = evaluator0.evaluate(X, y)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 156.4 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)
#
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:02

# %%
evaluator0.param_bg
# Out:
# {'loss_fn': -10, 'loss_fp': -1, 'gain_tp': 1, 'gain_tn': 1}

# %%
evaluator0.get_mean_val_scores()
# Out:
# {'auc': 0.5,
#  'accuracy': 0.9192224309871369,
#  'recall': 0.0,
#  'f1_score': 0.0,
#  'business_gain': 0.6741643384309018,
#  'fit_time': 0.0010845661163330078,
#  'tn': 12720.2,
#  'tp': 0.0,
#  'fn': 1117.8,
#  'fp': 0.0}

# %%
evaluator0.plot_conf_mat()

# %%
_ = evaluator0.plot_evaluation_scores()

# %%
fig = evaluator0.plot_roc_curve()

# %%
evaluator0.get_mean_val_scores()
# Out:
# {'auc': 0.5,
#  'accuracy': 0.9192224309871369,
#  'recall': 0.0,
#  'f1_score': 0.0,
#  'business_gain': 0.6741643384309018,
#  'fit_time': 0.0010845661163330078,
#  'tn': 12720.2,
#  'tp': 0.0,
#  'fn': 1117.8,
#  'fp': 0.0}

# %% [markdown]
# # Régression logistique sur toutes les features, échantillon 30%

# %% [markdown]
# ## Avec cuml

# %%
pipe_cuml = CuPipeline(
    [
        ("imputer", CuSimpleImputer(copy=False)),
        # ("std", VarianceSelector(copy=False)),
        ("scaler", CuStandardScaler(copy=False)),
        ("clf", cuml.LogisticRegression()),
    ]
)

# %%
X, y = read_sample(to_cpu=False)
evaluator_cuml = EvaluatorCV(pipe=pipe_cuml, device="GPU")
evaluator_cuml.evaluate(X, y)
# Out:
# Info X :
# <class 'cudf.core.dataframe.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 158.6 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)
# Durée de l'évaluation en validation croisée sur GPU (5 folds): 0:00:16

# %%
evaluator_cuml.get_mean_val_scores()
# Out:
# {'auc': 0.7574572119950027,
#  'accuracy': 0.9186154098141228,
#  'recall': 0.033280589619204264,
#  'f1_score': 0.06185652080455382,
#  'business_gain': 0.6825913749005054,
#  'fit_time': 1.1020913124084473,
#  'tn': 12674.6,
#  'tp': 37.2,
#  'fn': 1080.6,
#  'fp': 45.6}

# %%
pd.Series(evaluator_cuml.get_model_params())
# Out:
# handle                 <pylibraft.common.handle.Handle object at 0x7f8578849da0>
# verbose                                                                        4
# output_type                                                                input
# penalty                                                                       l2
# tol                                                                       0.0001
# C                                                                            1.0
# fit_intercept                                                               True
# class_weight                                                                None
# max_iter                                                                    1000
# linesearch_max_iter                                                           50
# l1_ratio                                                                    None
# solver                                                                        qn
# dtype: object

# %% [markdown]
# ## Avec sklearn

# %%
pipe_sklearn = Pipeline(
    [
        ("imputer", SimpleImputer(copy=False)),
        ("scaler", StandardScaler(copy=False)),
        (
            "clf",
            LogisticRegression(
                solver="lbfgs",
                n_jobs=14,
                max_iter=1000,
                warm_start=False,
                random_state=VAL_SEED,
            ),
        ),
    ]
)

# %%
X, y = read_sample(to_cpu=True)
evaluator_sklearn = EvaluatorCV(pipe=pipe_sklearn, device="CPU")
evaluator_sklearn.evaluate(X, y)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 156.4 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:10

# %%
evaluator_sklearn.get_mean_val_scores()
# Out:
# {'auc': 0.7589296024126553,
#  'accuracy': 0.9183986125162595,
#  'recall': 0.030953887153008553,
#  'f1_score': 0.05774735595447304,
#  'business_gain': 0.6818121868445001,
#  'fit_time': 1.1688735485076904,
#  'tn': 12674.2,
#  'tp': 34.6,
#  'fn': 1083.2,
#  'fp': 46.0}

# %%
pd.DataFrame(
    {
        "cuml": evaluator_cuml.get_model_params(),
        "sklearn lfgs": evaluator_sklearn.get_model_params(),
    }
)
# Out:
#                                                                           cuml  \
# handle               <pylibraft.common.handle.Handle object at 0x7f8578849da0>
# verbose                                                                      4
# output_type                                                              input
# penalty                                                                     l2
# tol                                                                     0.0001
# C                                                                          1.0
# fit_intercept                                                             True
# class_weight                                                              None
# max_iter                                                                  1000
# linesearch_max_iter                                                         50
# l1_ratio                                                                  None
# solver                                                                      qn
# dual                                                                       NaN
# intercept_scaling                                                          NaN
# multi_class                                                                NaN
# n_jobs                                                                     NaN
# random_state                                                               NaN
# warm_start                                                                 NaN
#
#                     sklearn lfgs
# handle                       NaN
# verbose                        0
# output_type                  NaN
# penalty                       l2
# tol                       0.0001
# C                            1.0
# fit_intercept               True
# class_weight                None
# max_iter                    1000
# linesearch_max_iter          NaN
# l1_ratio                    None
# solver                     lbfgs
# dual                       False
# intercept_scaling              1
# multi_class           deprecated
# n_jobs                        14
# random_state                  42
# warm_start                 False

# %%
pd.DataFrame(
    {
        "cuml": evaluator_cuml.get_mean_val_scores(),
        "sklearn lbfgs": evaluator_sklearn.get_mean_val_scores(),
    }
)
# Out:
#                        cuml  sklearn lbfgs
# auc                0.757457       0.758930
# accuracy           0.918615       0.918399
# recall             0.033281       0.030954
# f1_score           0.061857       0.057747
# business_gain      0.682591       0.681812
# fit_time           1.102091       1.168874
# tn             12674.600000   12674.200000
# tp                37.200000      34.600000
# fn              1080.600000    1083.200000
# fp                45.600000      46.000000

# %% [markdown]
# ## Réduction du nombre de features à l'aide d'un modèle à base d'arbres

# %% [markdown]
# ### Importances moyennes sur toutes les features et toutes les lignes

# %%
X = train.drop(columns=["SK_ID_CURR", "TARGET"]).to_pandas()
y = train["TARGET"].to_pandas()

print("Info X :")
print(X.info())
print("\nInfo y :")
print("Classe", y.__class__.__name__)
print("Type", y.dtype)
print("Shape", y.shape)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230634 entries, 0 to 230633
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 521.3 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (230634,)

# %%
clf = LGBMClassifier(
    n_threads=14,
    class_weight="balanced",
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

# %%
params = clf.get_params()
params
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': 'balanced',
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_leaves': 31,
#  'objective': 'binary',
#  'random_state': 42,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0,
#  'n_threads': 14,
#  'verbosity': -1}

# %%
t0 = time.time()
importances = importance_from_model(clf, X, y, n_splits=5)
duration = time.time() - t0
print(f"Durée du calcul des importances : {format_time(duration)}")
importances.head()
# Out:
# Durée du calcul des importances : 0:00:18
#                          importance_mean  importance_std  rank_importance  \
# feature
# EXT_SOURCE_1                       127.6        6.188699                1
# CREDIT_TO_ANNUITY_RATIO            127.6       10.358571                2
# EXT_SOURCE_2                       120.8        4.324350                3
# EXT_SOURCE_3                       105.0        8.888194                4
# DAYS_EMPLOYED                       70.6        2.509980                5
#
#                          missing_pct
# feature
# EXT_SOURCE_1               56.289185
# CREDIT_TO_ANNUITY_RATIO     0.003469
# EXT_SOURCE_2                0.208556
# EXT_SOURCE_3               19.816679
# DAYS_EMPLOYED              18.019459

# %%
fig_line_importance = plot_line_importance(importances)

# %%
fig_bar_importance = plot_bar_importances(importances, top=50)

# %% [markdown]
# ### Sauvegarde liste des features triée par importance

# %%
features_sorted_importance = list(importances.index)
save_pkl(features_sorted_importance, "features_sorted_importance")
# Out:
# Liste des features (Nb = 424) engistrée dans models/features_sorted_importance.pkl

# %% [markdown]
# ### Choix du nombre de features réduit

# %% [markdown]
# #### Sur une régression logistique

# %%
X_all_features, y = read_sample(to_cpu=True)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 156.4 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(copy=False)),
        ("scaler", StandardScaler(copy=False)),
        (
            "clf",
            LogisticRegression(
                solver="lbfgs", class_weight="balanced", n_jobs=14, max_iter=1000
            ),
        ),
    ]
)

# %%
business_gains = []
for i, n_features in enumerate([424, 60, 40, 20, 10]):
    features = features_sorted_importance[:n_features]
    print(f"\nAvec {n_features} features")
    X = X_all_features[features]
    evaluator = EvaluatorCV(pipe=pipe, cv=5, device="CPU", random_state=VAL_SEED)
    evaluator.evaluate(
        X,
        y,
    )

    # On retient les business gain et les fit_time dans une liste de dictionnaires pour pouvoir les comparer facilement ensuite
    business_gain_train, business_gain_val = evaluator.get_business_gain()

    fit_time = evaluator.get_mean_train_scores(prefix="")["fit_time"]
    dic_bg = {
        "Nb features": f"{len(features)} features",
        "business-gain_train": f"{business_gain_train:.4f}",
        "business_gain_val": f"{business_gain_val:.4f}",
        "fit_time": f"{fit_time * 1000:.0f}",
    }
    business_gains.append(dic_bg)

    # On compare les scores de train et de validation dans un graphique pour mieux visualiser le risque de surfit
    subtitle_plot = f"{evaluator.model.__class__.__name__} - class_weight'\nEchantillon 30% - {len(features)} features importantes"
    evaluator.plot_evaluation_scores(subtitle=subtitle_plot)

    if i == 0:
        business_gain_start = business_gain_val
    if business_gain_val < business_gain_start - 0.01:
        break

# On met les business_gains dans un tableau récapitulatif
business_gains_df = pd.DataFrame(business_gains)
# Out:
# Avec 424 features
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:12
# Business gain Train : 0.7101,	Business gain Validation : 0.6974
#
# Avec 60 features
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:05
# Business gain Train : 0.6924,	Business gain Validation : 0.6902
#
# Avec 40 features
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:05
# Business gain Train : 0.6877,	Business gain Validation : 0.6859

# %%
# On affiche le tableau récaputulatif
print("\nRécapitulatif sur la Régression logistique")
display(business_gains_df)
# Out:
# Récapitulatif sur la Régression logistique
#     Nb features business-gain_train business_gain_val fit_time
# 0  424 features              0.7101            0.6974     1551
# 1   60 features              0.6924            0.6902      555
# 2   40 features              0.6877            0.6859      446

# %%
"""
On choisit 60 features.
    - La perte de business_gain sur le jeu de validation est acceptable
    - On gagne du temps et de la consommation mémoire
    - Pas de surfit
"""
# Out:
# '\nOn choisit 60 features.\n    - La perte de business_gain sur le jeu de validation est acceptable\n    - On gagne du temps et de la consommation mémoire\n    - Pas de surfit\n'

# %% [markdown]
# # Données

# %%
n_features = 60

# %%
all_features = read_pkl("features_sorted_importance", verbose=False)
features = all_features[:n_features]

# %%
X_all_features, y = read_sample(to_cpu=True)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 156.4 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)

# %%
X = X_all_features[features].copy()

# %% [markdown]
# # Régression Logistique 60 features - Tests de stratégie de rééquilibrage

# %% [markdown]
# ## Création de l'expérience MLFlow pour tracer les expérimentations sur les stratégies de rééquilibrage

# %%
# On démarre l'interface web de MLFlow
# Ou tout simplement en ligne de commande :
# mlflow server --host 127.0.0.1 --port 5000 ou mlflow server --host localhost --port 5000
_ = start_mlflow_ui()
# Out:
# L'interface web mlflow est disponible à l'adresse http://127.0.0.1:5000

# %%
exp_balancing_id = create_or_load_experiment(
    name="balancing_strategies",
    description="Tests de stratégies de rééquilibrage sur échantillon de 30% en cross_validation 5 folds",
)
# Out:
# Création de l'expérience MLFlow 'balancing_strategies', ID = 920756896864399377

# %% [markdown]
# ## LOGREG Unbalanced 60 features

# %% [markdown]
# ### Initialisation

# %% [markdown]
# #### Pipe / modèle

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        (
            "clf",
            LogisticRegression(
                solver="lbfgs", class_weight=None, n_jobs=14, max_iter=1000
            ),
        ),
    ]
)

# %%
evaluator1 = EvaluatorCV(pipe=pipe, cv=5, device="CPU", random_state=VAL_SEED)

# %%
run_name = "logreg_unbalanced"
run_tags = {"balancing": evaluator1.balance_str}
run_description = "Régression Logistique non optimisée - unbalanced"

# %% [markdown]
# #### Exécution dans un run mlflow

# %%
with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator1.evaluate(X, y)
    _ = evaluator1.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:06
# Business gain Train : 0.6781,	Business gain Validation : 0.6780

# %% [markdown]
# #### Traçage des scores et des paramètres dans mlflow

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator1.get_mean_val_scores(prefix="val_")
    train_scores = evaluator1.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator1.get_model_params(), metric=evaluator1.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator1.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig((fig))
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator1.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig((fig))
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator1.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig((fig))
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# ### Ajout au tableau comparatif

# %%
cmp = ComparativeTable(title="Comparatif Rééquilibrage")
cmp.add(
    evaluator0,
)
cmp.set_column_format(dic_format={"fit_time": "{:.1f}", "fn": "{:.1f}", "fp": "{:.1f}"})
cmp.set_duration_format({"fit_time": "{:.1f}"})
cmp.set_column_order(
    [
        "model_name",
        "balancing",
        "business_gain",
        "auc",
        "accuracy",
        "recall",
        "f1_score",
        "fit_time",
        "fn",
        "fp",
        "n_rows",
        "n_feat.",
    ]
)
cmp.add(evaluator1)
cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name   balancing business_gain     auc accuracy  recall  \
# 0     DummyClassifier  Unbalanced        0.6742  0.5000   0.9192  0.0000
# 1  LogisticRegression  Unbalanced        0.6780  0.7524   0.9189  0.0152
#
#   f1_score fit_time      fn    fp  n_rows  n_feat.
# 0   0.0000      0.0  1117.8   0.0   69190      424
# 1   0.0294      0.6  1100.8  21.4   69190       60

# %% [markdown]
# ## Class_weight

# %% [markdown]
# ### Exécution

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        (
            "clf",
            LogisticRegression(
                solver="lbfgs", class_weight="balanced", n_jobs=14, max_iter=1000
            ),
        ),
    ]
)

# %%
evaluator2 = EvaluatorCV(pipe=pipe, cv=5, device="CPU", random_state=VAL_SEED)

# %%
run_name = "logreg_weight"
run_tags = {"balancing": evaluator2.balance_str}
run_description = "Régression Logistique non optimisée - class_weight"

# %% [markdown]
# #### Exécution dans un run mlflow

# %%
with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator2.evaluate(X, y)
    _ = evaluator2.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur CPU (5 folds): 0:00:09
# Business gain Train : 0.6924,	Business gain Validation : 0.6902

# %% [markdown]
# #### Traçage des scores et des paramètres dans mlflow

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator2.get_mean_val_scores(prefix="val_")
    train_scores = evaluator2.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator2.get_model_params(), metric=evaluator2.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator2.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator2.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator2.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# ### Ajout au tableau comparatif

# %%
cmp.add(evaluator2)

cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name              balancing business_gain     auc accuracy  \
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60

# %% [markdown]
# ## SMOTE (paramètres par défaut)

# %% [markdown]
# ### Exécution

# %%
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LogisticRegression(solver="lbfgs", n_jobs=14, max_iter=1000),
        ),
    ]
)

# %%
evaluator3 = EvaluatorCV(pipe=pipe, device="cpu", cv=5, random_state=42)
run_name = "logreg_smote"
run_tags = {"balancing": evaluator3.balance_str}
run_description = "Régression Logistique non optimisée - smote"

with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator3.evaluate(X, y)
    _ = evaluator3.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:08
# Business gain Train : 0.6925,	Business gain Validation : 0.6906

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator3.get_mean_val_scores(prefix="val_")
    train_scores = evaluator3.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator3.get_model_params(), metric=evaluator3.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### LOGREG SMOTE - Ajout au tableau comparatif

# %%
cmp.add(evaluator3)

cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name              balancing business_gain     auc accuracy  \
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
# 3  LogisticRegression                  SMOTE        0.6906  0.7500   0.6936
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60
# 3  0.6822   0.2646      0.8   355.2  3884.2   69190       60

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator3.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator3.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator3.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# # Tests rééquilibrage pour LightGBM 60 features

# %%
n_features = 60

# %%
all_features = read_pkl("features_sorted_importance", verbose=False)
features = all_features[:n_features]

# %%
X_all_features, y = read_sample(to_cpu=True)
# Out:
# Info X :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69190 entries, 0 to 69189
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float64(271), int64(7)
# memory usage: 156.4 MB
# None
#
# Info y :
# Classe Series
# Type int64
# Shape (69190,)

# %%
X = X_all_features[features]

# %% [markdown]
# ## LightGBM Unbalanced

# %% [markdown]
# ### Exécution LightGBM Unbalanced

# %%
model = LGBMClassifier(
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

evaluator4 = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)
run_name = "lightgbm_unbalanced"
run_tags = {"balancing": evaluator4.balance_str}
run_description = "LightGBM non optimisée - Unbalanced"

with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator4.evaluate(X, y)
    _ = evaluator4.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:04
# Business gain Train : 0.7160,	Business gain Validation : 0.6854

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator4.get_mean_val_scores(prefix="val_")
    train_scores = evaluator4.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator4.get_model_params(), metric=evaluator4.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator4.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator4.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator4.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# ### Ajout au tableau comparatif

# %%
cmp.add(evaluator4)
cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name              balancing business_gain     auc accuracy  \
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
# 3  LogisticRegression                  SMOTE        0.6906  0.7500   0.6936
# 4      LGBMClassifier             Unbalanced        0.6854  0.7672   0.9194
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60
# 3  0.6822   0.2646      0.8   355.2  3884.2   69190       60
# 4  0.0419   0.0774      0.4  1071.0    44.8   69190       60

# %% [markdown]
# ## LightGBM Class_weight

# %% [markdown]
# ### Exécution LightGBM Class_weight

# %%
model = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

evaluator5 = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)
run_name = "lightgbm_class_weight"
run_tags = {"balancing": evaluator5.balance_str}
run_description = "LightGBM non optimisée - Class_weight"

with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator5.evaluate(X, y)
    _ = evaluator5.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:04
# Business gain Train : 0.8199,	Business gain Validation : 0.7226

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator5.get_mean_val_scores(prefix="val_")
    train_scores = evaluator5.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator5.get_model_params(), metric=evaluator5.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator5.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator5.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator5.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# ### Ajout au tableau comparatif

# %%
cmp.add(evaluator5)
cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name              balancing business_gain     auc accuracy  \
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
# 3  LogisticRegression                  SMOTE        0.6906  0.7500   0.6936
# 4      LGBMClassifier             Unbalanced        0.6854  0.7672   0.9194
# 5      LGBMClassifier  class_weight=balanced        0.7226  0.7665   0.7622
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60
# 3  0.6822   0.2646      0.8   355.2  3884.2   69190       60
# 4  0.0419   0.0774      0.4  1071.0    44.8   69190       60
# 5  0.6135   0.2942      0.4   432.0  2858.0   69190       60

# %% [markdown]
# ## SMOTE LightGBM

# %% [markdown]
# ### Exécution smote lightGBM

# %%
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LGBMClassifier(
                n_threads=14,
                objective="binary",
                random_state=VAL_SEED,
                verbosity=-1,  # Pour ne pas voir les logs
            ),
        ),
    ]
)

# %%
evaluator6 = EvaluatorCV(pipe=pipe, device="cpu", cv=5, random_state=VAL_SEED)
run_name = "lightgbm_smote"
run_tags = {"balancing": evaluator6.balance_str}
run_description = "LightGBM non optimisée - SMOTE"

with mlflow.start_run(
    experiment_id=exp_balancing_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator6.evaluate(X, y)
    _ = evaluator6.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:07
# Business gain Train : 0.7043,	Business gain Validation : 0.6917

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator6.get_mean_val_scores(prefix="val_")
    train_scores = evaluator6.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = merge_dicts_with_prefixes(
        model=evaluator6.get_model_params(), metric=evaluator4.get_metric_params()
    )
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator6.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_evaluation_scores.png")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator6.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_confusion_matrix.png")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator6.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    img = pil_image_from_fig(fig)
    mlflow.log_image(img, artifact_file="plot_roc_curve.png")

# %% [markdown]
# ### Ajout au tableau comparatif

# %%
cmp.add(evaluator6)
cmp.display()
# Out:
# Comparatif Rééquilibrage
#            model_name              balancing business_gain     auc accuracy  \
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
# 3  LogisticRegression                  SMOTE        0.6906  0.7500   0.6936
# 4      LGBMClassifier             Unbalanced        0.6854  0.7672   0.9194
# 5      LGBMClassifier  class_weight=balanced        0.7226  0.7665   0.7622
# 6      LGBMClassifier                  SMOTE        0.6917  0.7296   0.9054
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60
# 3  0.6822   0.2646      0.8   355.2  3884.2   69190       60
# 4  0.0419   0.0774      0.4  1071.0    44.8   69190       60
# 5  0.6135   0.2942      0.4   432.0  2858.0   69190       60
# 6  0.1040   0.1507      0.9  1001.6   307.6   69190       60

# %% [markdown]
# # Meilleure stratégie de rééquilibrage

# %%
# On trie le tableau par Business Gain de validation
cmp.display(sort_by=["business_gain"])
# Out:
# Comparatif Rééquilibrage trié par ['business_gain']
#            model_name              balancing business_gain     auc accuracy  \
# 5      LGBMClassifier  class_weight=balanced        0.7226  0.7665   0.7622
# 6      LGBMClassifier                  SMOTE        0.6917  0.7296   0.9054
# 3  LogisticRegression                  SMOTE        0.6906  0.7500   0.6936
# 2  LogisticRegression  class_weight=balanced        0.6902  0.7534   0.6922
# 4      LGBMClassifier             Unbalanced        0.6854  0.7672   0.9194
# 1  LogisticRegression             Unbalanced        0.6780  0.7524   0.9189
# 0     DummyClassifier             Unbalanced        0.6742  0.5000   0.9192
#
#    recall f1_score fit_time      fn      fp  n_rows  n_feat.
# 5  0.6135   0.2942      0.4   432.0  2858.0   69190       60
# 6  0.1040   0.1507      0.9  1001.6   307.6   69190       60
# 3  0.6822   0.2646      0.8   355.2  3884.2   69190       60
# 2  0.6849   0.2644      1.3   352.2  3907.6   69190       60
# 4  0.0419   0.0774      0.4  1071.0    44.8   69190       60
# 1  0.0152   0.0294      0.6  1100.8    21.4   69190       60
# 0  0.0000   0.0000      0.0  1117.8     0.0   69190      424

# %%
"""
Avec les paramètres par défaut, la stratégie de rééquilibrage la plus prometteuse est class_weighted pour le meilleur modèle : lightgbm.
Celle-ci peut-être améliorée en jouant sur les poids,
tout comme SMOTE pourrait être amélioré en jourant sur le nombre de voisins
"""
# Out:
# '\nAvec les paramètres par défaut, la stratégie de rééquilibrage la plus prometteuse est class_weighted.\nCelle-ci peut-être améliorée en jouant sur les poids,\ntout comme SMOTE pourrait être amélioré en jourant sur le nombre de voisins\n'

# %%
# Sauvegarde de l'objet
save_pkl(cmp, filename="cmp_balancing", title="Comparatif Rééquilibrage")
# Sauvegarde en tant que liste de dictionnaires réutilisable dans une autre classe car
# si on modifie la classe en cours de projet, on ne pourra plus lire l'objet.
cmp.save("cmp_balancing_table")
# Out:
# Comparatif Rééquilibrage engistré(e) dans models/cmp_balancing.pkl
# Tableau comparatif enregistré dans models/cmp_balancing_table.pkl

# %% [markdown]
# # Nombre de features idéal avec RFECV pour le train non réduit

# %% [markdown]
# ## Lecture du train

# %%
X, y = read_train(features=[])
# Out:
# Memory usage of dataframe is 532.18 MB
# Memory usage after optimization is: 303.43 MB
# Decreased by 43.0%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float32(242), float64(29), int32(5), int64(2)
# memory usage: 305.7 MB

# %% [markdown]
# # Meilleures features pour chaque modèle - RFECV

# %% [markdown]
# ## Meilleures features pour le modèle REGLOG (RFECV sur La Régression Logistique avec SMOTE)

# %%
X.shape
# Out:
# (230634, 424)

# %%
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LogisticRegression(solver="lbfgs", n_jobs=14, max_iter=500),
        ),
    ]
)

# %%
t0 = time.time()
selector_logreg = RfecvSelector(
    pipe=pipe,
    min_features=20,
    cv=5,
)
selector_logreg.fit(X, y)
duration = time.time() - t0
print(f"\nDurée (hh:mm:ss) : {format_time(duration)}")
# Out:
# self.model type <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 424 features -> Auc = 0.7524
# 423 features -> Auc = 0.7524
# 422 features -> Auc = 0.7524
# 421 features -> Auc = 0.7525
# 420 features -> Auc = 0.7525
# 419 features -> Auc = 0.7525
# 418 features -> Auc = 0.7525
# 417 features -> Auc = 0.7525
# 416 features -> Auc = 0.7525
# 415 features -> Auc = 0.7525
# 414 features -> Auc = 0.7525
# 413 features -> Auc = 0.7525
# 412 features -> Auc = 0.7525
# 411 features -> Auc = 0.7525
# 410 features -> Auc = 0.7525
# 409 features -> Auc = 0.7525
# 408 features -> Auc = 0.7525
# 407 features -> Auc = 0.7525
# 406 features -> Auc = 0.7525
# 405 features -> Auc = 0.7526
# 404 features -> Auc = 0.7526
# 403 features -> Auc = 0.7528
# 402 features -> Auc = 0.7528
# 401 features -> Auc = 0.7528
# 400 features -> Auc = 0.7528
# 399 features -> Auc = 0.7528
# 398 features -> Auc = 0.7528
# 397 features -> Auc = 0.7528
# 396 features -> Auc = 0.7528
# 395 features -> Auc = 0.7528
# 394 features -> Auc = 0.7529
# 393 features -> Auc = 0.7528
# 392 features -> Auc = 0.7529
# 391 features -> Auc = 0.7529
# 390 features -> Auc = 0.7529
# 389 features -> Auc = 0.7529
# 388 features -> Auc = 0.7530
# 387 features -> Auc = 0.7530
# 386 features -> Auc = 0.7530
# 385 features -> Auc = 0.7529
# 384 features -> Auc = 0.7529
# 383 features -> Auc = 0.7529
# 382 features -> Auc = 0.7529
# 381 features -> Auc = 0.7529
# 380 features -> Auc = 0.7532
# 379 features -> Auc = 0.7531
# 378 features -> Auc = 0.7532
# 377 features -> Auc = 0.7532
# 376 features -> Auc = 0.7532
# 375 features -> Auc = 0.7532
# 374 features -> Auc = 0.7532
# 373 features -> Auc = 0.7532
# 372 features -> Auc = 0.7532
# 371 features -> Auc = 0.7533
# 370 features -> Auc = 0.7533
# 369 features -> Auc = 0.7533
# 368 features -> Auc = 0.7533
# 367 features -> Auc = 0.7533
# 366 features -> Auc = 0.7533
# 365 features -> Auc = 0.7534
# 364 features -> Auc = 0.7533
# 363 features -> Auc = 0.7533
# 362 features -> Auc = 0.7534
# 361 features -> Auc = 0.7534
# 360 features -> Auc = 0.7534
# 359 features -> Auc = 0.7535
# 358 features -> Auc = 0.7534
# 357 features -> Auc = 0.7535
# 356 features -> Auc = 0.7536
# 355 features -> Auc = 0.7536
# 354 features -> Auc = 0.7536
# 353 features -> Auc = 0.7536
# 352 features -> Auc = 0.7536
# 351 features -> Auc = 0.7537
# 350 features -> Auc = 0.7536
# 349 features -> Auc = 0.7536
# 348 features -> Auc = 0.7537
# 347 features -> Auc = 0.7537
# 346 features -> Auc = 0.7537
# 345 features -> Auc = 0.7537
# 344 features -> Auc = 0.7538
# 343 features -> Auc = 0.7538
# 342 features -> Auc = 0.7538
# 341 features -> Auc = 0.7538
# 340 features -> Auc = 0.7539
# 339 features -> Auc = 0.7539
# 338 features -> Auc = 0.7540
# 337 features -> Auc = 0.7540
# 336 features -> Auc = 0.7540
# 335 features -> Auc = 0.7540
# 334 features -> Auc = 0.7541
# 333 features -> Auc = 0.7540
# 332 features -> Auc = 0.7541
# 331 features -> Auc = 0.7541
# 330 features -> Auc = 0.7541
# 329 features -> Auc = 0.7540
# 328 features -> Auc = 0.7540
# 327 features -> Auc = 0.7540
# 326 features -> Auc = 0.7541
# 325 features -> Auc = 0.7541
# 324 features -> Auc = 0.7541
# 323 features -> Auc = 0.7541
# 322 features -> Auc = 0.7542
# 321 features -> Auc = 0.7542
# 320 features -> Auc = 0.7542
# 319 features -> Auc = 0.7542
# 318 features -> Auc = 0.7542
# 317 features -> Auc = 0.7542
# 316 features -> Auc = 0.7542
# 315 features -> Auc = 0.7542
# 314 features -> Auc = 0.7542
# 313 features -> Auc = 0.7542
# 312 features -> Auc = 0.7542
# 311 features -> Auc = 0.7543
# 310 features -> Auc = 0.7543
# 309 features -> Auc = 0.7543
# 308 features -> Auc = 0.7543
# 307 features -> Auc = 0.7543
# 306 features -> Auc = 0.7544
# 305 features -> Auc = 0.7544
# 304 features -> Auc = 0.7544
# 303 features -> Auc = 0.7544
# 302 features -> Auc = 0.7544
# 301 features -> Auc = 0.7544
# 300 features -> Auc = 0.7544
# 299 features -> Auc = 0.7544
# 298 features -> Auc = 0.7545
# 297 features -> Auc = 0.7545
# 296 features -> Auc = 0.7546
# 295 features -> Auc = 0.7546
# 294 features -> Auc = 0.7546
# 293 features -> Auc = 0.7544
# 292 features -> Auc = 0.7544
# 291 features -> Auc = 0.7544
# 290 features -> Auc = 0.7544
# 289 features -> Auc = 0.7545
# 288 features -> Auc = 0.7544
# 287 features -> Auc = 0.7544
# 286 features -> Auc = 0.7545
# 285 features -> Auc = 0.7545
# 284 features -> Auc = 0.7545
# 283 features -> Auc = 0.7545
# 282 features -> Auc = 0.7545
# 281 features -> Auc = 0.7545
# 280 features -> Auc = 0.7546
# 279 features -> Auc = 0.7546
# 278 features -> Auc = 0.7546
# 277 features -> Auc = 0.7546
# 276 features -> Auc = 0.7546
# 275 features -> Auc = 0.7546
# 274 features -> Auc = 0.7546
# 273 features -> Auc = 0.7546
# 272 features -> Auc = 0.7546
# 271 features -> Auc = 0.7548
# 270 features -> Auc = 0.7548
# 269 features -> Auc = 0.7549
# 268 features -> Auc = 0.7548
# 267 features -> Auc = 0.7548
# 266 features -> Auc = 0.7548
# 265 features -> Auc = 0.7549
# 264 features -> Auc = 0.7550
# 263 features -> Auc = 0.7550
# 262 features -> Auc = 0.7550
# 261 features -> Auc = 0.7550
# 260 features -> Auc = 0.7550
# 259 features -> Auc = 0.7551
# 258 features -> Auc = 0.7550
# 257 features -> Auc = 0.7550
# 256 features -> Auc = 0.7549
# 255 features -> Auc = 0.7549
# 254 features -> Auc = 0.7548
# 253 features -> Auc = 0.7548
# 252 features -> Auc = 0.7550
# 251 features -> Auc = 0.7550
# 250 features -> Auc = 0.7550
# 249 features -> Auc = 0.7550
# 248 features -> Auc = 0.7550
# 247 features -> Auc = 0.7549
# 246 features -> Auc = 0.7549
# 245 features -> Auc = 0.7549
# 244 features -> Auc = 0.7549
# 243 features -> Auc = 0.7548
# 242 features -> Auc = 0.7548
# 241 features -> Auc = 0.7548
# 240 features -> Auc = 0.7549
# 239 features -> Auc = 0.7549
# 238 features -> Auc = 0.7549
# 237 features -> Auc = 0.7550
# 236 features -> Auc = 0.7551
# 235 features -> Auc = 0.7551
# 234 features -> Auc = 0.7552
# 233 features -> Auc = 0.7552
# 232 features -> Auc = 0.7552
# 231 features -> Auc = 0.7552
# 230 features -> Auc = 0.7551
# 229 features -> Auc = 0.7552
# 228 features -> Auc = 0.7552
# 227 features -> Auc = 0.7552
# 226 features -> Auc = 0.7551
# 225 features -> Auc = 0.7552
# 224 features -> Auc = 0.7552
# 223 features -> Auc = 0.7553
# 222 features -> Auc = 0.7551
# 221 features -> Auc = 0.7550
# 220 features -> Auc = 0.7550
# 219 features -> Auc = 0.7550
# 218 features -> Auc = 0.7550
# 217 features -> Auc = 0.7550
# 216 features -> Auc = 0.7551
# 215 features -> Auc = 0.7550
# 214 features -> Auc = 0.7551
# 213 features -> Auc = 0.7551
# 212 features -> Auc = 0.7550
# 211 features -> Auc = 0.7550
# 210 features -> Auc = 0.7550
# 209 features -> Auc = 0.7549
# 208 features -> Auc = 0.7549
# 207 features -> Auc = 0.7548
# 206 features -> Auc = 0.7549
# 205 features -> Auc = 0.7549
# 204 features -> Auc = 0.7549
# 203 features -> Auc = 0.7549
# 202 features -> Auc = 0.7550
# 201 features -> Auc = 0.7551
# 200 features -> Auc = 0.7550
# 199 features -> Auc = 0.7550
# 198 features -> Auc = 0.7551
# 197 features -> Auc = 0.7551
# 196 features -> Auc = 0.7551
# 195 features -> Auc = 0.7551
# 194 features -> Auc = 0.7553
# 193 features -> Auc = 0.7553
# 192 features -> Auc = 0.7552
# 191 features -> Auc = 0.7554
# 190 features -> Auc = 0.7553
# 189 features -> Auc = 0.7553
# 188 features -> Auc = 0.7552
# 187 features -> Auc = 0.7551
# 186 features -> Auc = 0.7551
# 185 features -> Auc = 0.7551
# 184 features -> Auc = 0.7552
# 183 features -> Auc = 0.7552
# 182 features -> Auc = 0.7552
# 181 features -> Auc = 0.7552
# 180 features -> Auc = 0.7551
# 179 features -> Auc = 0.7551
# 178 features -> Auc = 0.7551
# 177 features -> Auc = 0.7551
# 176 features -> Auc = 0.7550
# 175 features -> Auc = 0.7550
# 174 features -> Auc = 0.7550
# 173 features -> Auc = 0.7550
# 172 features -> Auc = 0.7552
# 171 features -> Auc = 0.7551
# 170 features -> Auc = 0.7550
# 169 features -> Auc = 0.7549
# 168 features -> Auc = 0.7551
# 167 features -> Auc = 0.7551
# 166 features -> Auc = 0.7553
# 165 features -> Auc = 0.7553
# 164 features -> Auc = 0.7552
# 163 features -> Auc = 0.7551
# 162 features -> Auc = 0.7550
# 161 features -> Auc = 0.7550
# 160 features -> Auc = 0.7550
# 159 features -> Auc = 0.7549
# 158 features -> Auc = 0.7547
# 157 features -> Auc = 0.7548
# 156 features -> Auc = 0.7548
# 155 features -> Auc = 0.7548
# 154 features -> Auc = 0.7548
# 153 features -> Auc = 0.7548
# 152 features -> Auc = 0.7549
# 151 features -> Auc = 0.7549
# 150 features -> Auc = 0.7549
# 149 features -> Auc = 0.7548
# 148 features -> Auc = 0.7549
# 147 features -> Auc = 0.7550
# 146 features -> Auc = 0.7551
# 145 features -> Auc = 0.7553
# 144 features -> Auc = 0.7552
# 143 features -> Auc = 0.7552
# 142 features -> Auc = 0.7552
# 141 features -> Auc = 0.7553
# 140 features -> Auc = 0.7551
# 139 features -> Auc = 0.7552
# 138 features -> Auc = 0.7553
# 137 features -> Auc = 0.7554
# 136 features -> Auc = 0.7555
# 135 features -> Auc = 0.7555
# 134 features -> Auc = 0.7557
# 133 features -> Auc = 0.7558
# 132 features -> Auc = 0.7557
# 131 features -> Auc = 0.7556
# 130 features -> Auc = 0.7556
# 129 features -> Auc = 0.7556
# 128 features -> Auc = 0.7557
# 127 features -> Auc = 0.7557
# 126 features -> Auc = 0.7558
# 125 features -> Auc = 0.7558
# 124 features -> Auc = 0.7557
# 123 features -> Auc = 0.7558
# 122 features -> Auc = 0.7560
# 121 features -> Auc = 0.7559
# 120 features -> Auc = 0.7560
# 119 features -> Auc = 0.7564
# 118 features -> Auc = 0.7564
# 117 features -> Auc = 0.7564
# 116 features -> Auc = 0.7564
# 115 features -> Auc = 0.7565
# 114 features -> Auc = 0.7563
# 113 features -> Auc = 0.7562
# 112 features -> Auc = 0.7563
# 111 features -> Auc = 0.7564
# 110 features -> Auc = 0.7564
# 109 features -> Auc = 0.7563
# 108 features -> Auc = 0.7565
# 107 features -> Auc = 0.7562
# 106 features -> Auc = 0.7563
# 105 features -> Auc = 0.7562
# 104 features -> Auc = 0.7564
# 103 features -> Auc = 0.7565
# 102 features -> Auc = 0.7565
# 101 features -> Auc = 0.7560
# 100 features -> Auc = 0.7557
# 99 features -> Auc = 0.7556
# 98 features -> Auc = 0.7556
# 97 features -> Auc = 0.7556
# 96 features -> Auc = 0.7558
# 95 features -> Auc = 0.7560
# 94 features -> Auc = 0.7558
# 93 features -> Auc = 0.7558
# 92 features -> Auc = 0.7558
# 91 features -> Auc = 0.7558
# 90 features -> Auc = 0.7562
# 89 features -> Auc = 0.7561
# 88 features -> Auc = 0.7561
# 87 features -> Auc = 0.7561
# 86 features -> Auc = 0.7560
# 85 features -> Auc = 0.7560
# 84 features -> Auc = 0.7559
# 83 features -> Auc = 0.7557
# 82 features -> Auc = 0.7554
# 81 features -> Auc = 0.7554
# 80 features -> Auc = 0.7555
# 79 features -> Auc = 0.7558
# 78 features -> Auc = 0.7561
# 77 features -> Auc = 0.7561
# 76 features -> Auc = 0.7559
# 75 features -> Auc = 0.7559
# 74 features -> Auc = 0.7557
# 73 features -> Auc = 0.7557
# 72 features -> Auc = 0.7559
# 71 features -> Auc = 0.7558
# 70 features -> Auc = 0.7559
# 69 features -> Auc = 0.7559
# 68 features -> Auc = 0.7557
# 67 features -> Auc = 0.7553
# 66 features -> Auc = 0.7554
# 65 features -> Auc = 0.7554
# 64 features -> Auc = 0.7554
# 63 features -> Auc = 0.7554
# 62 features -> Auc = 0.7555
# 61 features -> Auc = 0.7558
# 60 features -> Auc = 0.7559
# 59 features -> Auc = 0.7560
# 58 features -> Auc = 0.7561
# 57 features -> Auc = 0.7563
# 56 features -> Auc = 0.7563
# 55 features -> Auc = 0.7560
# 54 features -> Auc = 0.7560
# 53 features -> Auc = 0.7562
# 52 features -> Auc = 0.7563
# 51 features -> Auc = 0.7559
# 50 features -> Auc = 0.7555
# 49 features -> Auc = 0.7556
# 48 features -> Auc = 0.7555
# 47 features -> Auc = 0.7554
# 46 features -> Auc = 0.7554
# 45 features -> Auc = 0.7553
# 44 features -> Auc = 0.7550
# 43 features -> Auc = 0.7549
# 42 features -> Auc = 0.7547
# 41 features -> Auc = 0.7543
# 40 features -> Auc = 0.7544
# 39 features -> Auc = 0.7544
# 38 features -> Auc = 0.7545
# 37 features -> Auc = 0.7544
# 36 features -> Auc = 0.7542
# 35 features -> Auc = 0.7541
# 34 features -> Auc = 0.7540
# 33 features -> Auc = 0.7541
# 32 features -> Auc = 0.7540
# 31 features -> Auc = 0.7535
# 30 features -> Auc = 0.7533
# 29 features -> Auc = 0.7519
# 28 features -> Auc = 0.7517
# 27 features -> Auc = 0.7505
# 26 features -> Auc = 0.7495
# 25 features -> Auc = 0.7484
# 24 features -> Auc = 0.7487
# 23 features -> Auc = 0.7481
# 22 features -> Auc = 0.7476
# 21 features -> Auc = 0.7474
# 20 features -> Auc = 0.7471
#
# Durée (hh:mm:ss) : 3:05:18

# %%
print(f"{len(selector_logreg.best_features)} features ont été sélectionnées :")
print(selector_logreg.best_features)
print("Meilleur score de validation (AUC) :", selector_logreg.best_score)
# Out:
# 103 features ont été sélectionnées :
# ['CODE_GENDER', 'FLAG_OWN_CAR', 'CNT_CHILDREN', 'AMT_ANNUITY', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'FLAG_EMP_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REG_REGION_NOT_WORK_REGION', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'EMERGENCYSTATE_MODE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_18', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'CREDIT_TO_GOODS_RATIO', 'ANNUITY_TO_INCOME_RATIO', 'NAME_CONTRACT_TYPE_Revolvingloans', 'NAME_TYPE_SUITE_Family', 'NAME_TYPE_SUITE_Spousepartner', 'NAME_INCOME_TYPE_Commercialassociate', 'NAME_INCOME_TYPE_Stateservant', 'NAME_INCOME_TYPE_Student', 'NAME_EDUCATION_TYPE_Highereducation', 'NAME_EDUCATION_TYPE_Incompletehigher', 'NAME_FAMILY_STATUS_Married', 'NAME_FAMILY_STATUS_Singlenotmarried', 'OCCUPATION_TYPE_Corestaff', 'OCCUPATION_TYPE_Highskilltechstaff', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Managers', 'OCCUPATION_TYPE_Medicinestaff', 'OCCUPATION_TYPE_Salesstaff', 'OCCUPATION_TYPE_NA', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WEEKDAY_APPR_PROCESS_START_SATURDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'WEEKDAY_APPR_PROCESS_START_THURSDAY', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'ORGANIZATION_TYPE_Other', 'WALLSMATERIAL_MODE_Panel', 'BURO_DAYS_CREDIT_MIN', 'BURO_DAYS_CREDIT_VAR', 'BURO_AMT_CREDIT_SUM_MAX', 'BURO_CREDIT_ACTIVE_Active_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'ACTIVE_DAYS_CREDIT_MAX', 'ACTIVE_AMT_CREDIT_SUM_SUM', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'PREV_AMT_ANNUITY_MIN', 'PREV_AMT_CREDIT_MIN', 'PREV_AMT_CREDIT_MAX', 'PREV_HOUR_APPR_PROCESS_START_MIN', 'PREV_CNT_PAYMENT_SUM', 'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN', 'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN', 'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN', 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN', 'PREV_NAME_CLIENT_TYPE_New_MEAN', 'PREV_NAME_CLIENT_TYPE_Repeater_MEAN', 'PREV_NAME_GOODS_CATEGORY_ClothingandAccessories_MEAN', 'PREV_NAME_GOODS_CATEGORY_Weapon_MEAN', 'PREV_NAME_PORTFOLIO_Cards_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN', 'PREV_NAME_YIELD_GROUP_low_action_MEAN', 'PREV_NAME_YIELD_GROUP_low_normal_MEAN', 'PREV_NAME_YIELD_GROUP_middle_MEAN', 'PREV_PRODUCT_COMBINATION_CashStreetlow_MEAN', 'PREV_PRODUCT_COMBINATION_CashXSelllow_MEAN', 'PREV_PRODUCT_COMBINATION_POShouseholdwithinterest_MEAN', 'APPROVED_AMT_ANNUITY_MAX', 'APPROVED_AMT_GOODS_PRICE_MAX', 'APPROVED_RATE_DOWN_PAYMENT_MAX', 'APPROVED_CNT_PAYMENT_MEAN', 'APPROVED_CNT_PAYMENT_SUM', 'REFUSED_DAYS_DECISION_MAX', 'POS_SK_DPD_MEAN', 'POS_COUNT', 'INSTAL_DBD_MAX', 'INSTAL_DBD_MEAN', 'INSTAL_DBD_SUM', 'INSTAL_PAYMENT_DIFF_MAX', 'INSTAL_PAYMENT_DIFF_MEAN', 'INSTAL_PAYMENT_DIFF_VAR', 'INSTAL_AMT_INSTALMENT_MAX', 'INSTAL_AMT_INSTALMENT_MEAN', 'INSTAL_AMT_INSTALMENT_SUM', 'INSTAL_AMT_PAYMENT_MIN', 'INSTAL_DAYS_ENTRY_PAYMENT_SUM', 'CC_AMT_BALANCE_MEAN', 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN', 'CC_CNT_DRAWINGS_ATM_CURRENT_MEAN']
# Meilleur score de validation (AUC) : 0.7565164550711643

# %%
selector_logreg.best_score
# Out:
# 0.7565164550711643

# %%
selector_logreg.plot_scores(y_lim=[0.75, 0.76])

# %% [markdown]
# ### Sauvegarde

# %%
save_pkl(selector_logreg.best_features, "features_rfecv_logreg")
# Out:
# Liste des features (Nb = 103) engistrée dans models/features_rfecv_logreg.pkl

# %% [markdown]
# ## Meilleures features pour le modèle LightGBM (RFECV sur LightGBM avec classweight)

# %%
X, y = read_train()
# Out:
# Memory usage of dataframe is 532.18 MB
# Memory usage after optimization is: 303.43 MB
# Decreased by 43.0%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Columns: 424 entries, CODE_GENDER to CC_CNT_DRAWINGS_CURRENT_VAR
# dtypes: bool(146), float32(242), float64(29), int32(5), int64(2)
# memory usage: 305.7 MB

# %% [markdown]
# ### RFECV avec lgbm class_weighted

# %%
start = time.time()
estimator_weighted = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,
)

t0 = time.time()
selector_lightgbm = RfecvSelector(
    pipe=estimator_weighted,
    min_features=4,
    cv=5,
    step=1,
)
selector_lightgbm.fit(X, y)

duration = time.time() - t0
print(f"\nDurée (hh:mm:ss) : {format_time(duration)}")
# Out:
# self.model type <class 'lightgbm.sklearn.LGBMClassifier'>
# 424 features -> Auc = 0.7804
# 423 features -> Auc = 0.7804
# 422 features -> Auc = 0.7804
# 421 features -> Auc = 0.7804
# 420 features -> Auc = 0.7804
# 419 features -> Auc = 0.7804
# 418 features -> Auc = 0.7804
# 417 features -> Auc = 0.7804
# 416 features -> Auc = 0.7804
# 415 features -> Auc = 0.7804
# 414 features -> Auc = 0.7804
# 413 features -> Auc = 0.7804
# 412 features -> Auc = 0.7804
# 411 features -> Auc = 0.7804
# 410 features -> Auc = 0.7804
# 409 features -> Auc = 0.7803
# 408 features -> Auc = 0.7803
# 407 features -> Auc = 0.7803
# 406 features -> Auc = 0.7803
# 405 features -> Auc = 0.7803
# 404 features -> Auc = 0.7803
# 403 features -> Auc = 0.7803
# 402 features -> Auc = 0.7803
# 401 features -> Auc = 0.7805
# 400 features -> Auc = 0.7803
# 399 features -> Auc = 0.7803
# 398 features -> Auc = 0.7803
# 397 features -> Auc = 0.7803
# 396 features -> Auc = 0.7803
# 395 features -> Auc = 0.7803
# 394 features -> Auc = 0.7803
# 393 features -> Auc = 0.7803
# 392 features -> Auc = 0.7803
# 391 features -> Auc = 0.7803
# 390 features -> Auc = 0.7803
# 389 features -> Auc = 0.7803
# 388 features -> Auc = 0.7803
# 387 features -> Auc = 0.7803
# 386 features -> Auc = 0.7803
# 385 features -> Auc = 0.7803
# 384 features -> Auc = 0.7803
# 383 features -> Auc = 0.7803
# 382 features -> Auc = 0.7803
# 381 features -> Auc = 0.7804
# 380 features -> Auc = 0.7803
# 379 features -> Auc = 0.7803
# 378 features -> Auc = 0.7803
# 377 features -> Auc = 0.7803
# 376 features -> Auc = 0.7803
# 375 features -> Auc = 0.7803
# 374 features -> Auc = 0.7803
# 373 features -> Auc = 0.7803
# 372 features -> Auc = 0.7803
# 371 features -> Auc = 0.7803
# 370 features -> Auc = 0.7803
# 369 features -> Auc = 0.7803
# 368 features -> Auc = 0.7803
# 367 features -> Auc = 0.7803
# 366 features -> Auc = 0.7803
# 365 features -> Auc = 0.7803
# 364 features -> Auc = 0.7803
# 363 features -> Auc = 0.7803
# 362 features -> Auc = 0.7803
# 361 features -> Auc = 0.7803
# 360 features -> Auc = 0.7803
# 359 features -> Auc = 0.7803
# 358 features -> Auc = 0.7803
# 357 features -> Auc = 0.7803
# 356 features -> Auc = 0.7803
# 355 features -> Auc = 0.7803
# 354 features -> Auc = 0.7803
# 353 features -> Auc = 0.7803
# 352 features -> Auc = 0.7803
# 351 features -> Auc = 0.7803
# 350 features -> Auc = 0.7803
# 349 features -> Auc = 0.7803
# 348 features -> Auc = 0.7803
# 347 features -> Auc = 0.7803
# 346 features -> Auc = 0.7803
# 345 features -> Auc = 0.7803
# 344 features -> Auc = 0.7803
# 343 features -> Auc = 0.7803
# 342 features -> Auc = 0.7803
# 341 features -> Auc = 0.7803
# 340 features -> Auc = 0.7803
# 339 features -> Auc = 0.7803
# 338 features -> Auc = 0.7803
# 337 features -> Auc = 0.7803
# 336 features -> Auc = 0.7803
# 335 features -> Auc = 0.7803
# 334 features -> Auc = 0.7803
# 333 features -> Auc = 0.7803
# 332 features -> Auc = 0.7803
# 331 features -> Auc = 0.7803
# 330 features -> Auc = 0.7803
# 329 features -> Auc = 0.7803
# 328 features -> Auc = 0.7803
# 327 features -> Auc = 0.7803
# 326 features -> Auc = 0.7803
# 325 features -> Auc = 0.7803
# 324 features -> Auc = 0.7803
# 323 features -> Auc = 0.7803
# 322 features -> Auc = 0.7803
# 321 features -> Auc = 0.7803
# 320 features -> Auc = 0.7803
# 319 features -> Auc = 0.7803
# 318 features -> Auc = 0.7803
# 317 features -> Auc = 0.7803
# 316 features -> Auc = 0.7803
# 315 features -> Auc = 0.7803
# 314 features -> Auc = 0.7803
# 313 features -> Auc = 0.7803
# 312 features -> Auc = 0.7803
# 311 features -> Auc = 0.7803
# 310 features -> Auc = 0.7803
# 309 features -> Auc = 0.7803
# 308 features -> Auc = 0.7803
# 307 features -> Auc = 0.7803
# 306 features -> Auc = 0.7803
# 305 features -> Auc = 0.7803
# 304 features -> Auc = 0.7803
# 303 features -> Auc = 0.7803
# 302 features -> Auc = 0.7803
# 301 features -> Auc = 0.7803
# 300 features -> Auc = 0.7803
# 299 features -> Auc = 0.7803
# 298 features -> Auc = 0.7803
# 297 features -> Auc = 0.7803
# 296 features -> Auc = 0.7803
# 295 features -> Auc = 0.7803
# 294 features -> Auc = 0.7803
# 293 features -> Auc = 0.7803
# 292 features -> Auc = 0.7805
# 291 features -> Auc = 0.7805
# 290 features -> Auc = 0.7805
# 289 features -> Auc = 0.7805
# 288 features -> Auc = 0.7806
# 287 features -> Auc = 0.7806
# 286 features -> Auc = 0.7806
# 285 features -> Auc = 0.7806
# 284 features -> Auc = 0.7806
# 283 features -> Auc = 0.7806
# 282 features -> Auc = 0.7806
# 281 features -> Auc = 0.7806
# 280 features -> Auc = 0.7806
# 279 features -> Auc = 0.7806
# 278 features -> Auc = 0.7806
# 277 features -> Auc = 0.7806
# 276 features -> Auc = 0.7806
# 275 features -> Auc = 0.7806
# 274 features -> Auc = 0.7806
# 273 features -> Auc = 0.7806
# 272 features -> Auc = 0.7806
# 271 features -> Auc = 0.7806
# 270 features -> Auc = 0.7807
# 269 features -> Auc = 0.7807
# 268 features -> Auc = 0.7807
# 267 features -> Auc = 0.7807
# 266 features -> Auc = 0.7807
# 265 features -> Auc = 0.7806
# 264 features -> Auc = 0.7804
# 263 features -> Auc = 0.7803
# 262 features -> Auc = 0.7803
# 261 features -> Auc = 0.7803
# 260 features -> Auc = 0.7803
# 259 features -> Auc = 0.7803
# 258 features -> Auc = 0.7802
# 257 features -> Auc = 0.7799
# 256 features -> Auc = 0.7800
# 255 features -> Auc = 0.7800
# 254 features -> Auc = 0.7800
# 253 features -> Auc = 0.7800
# 252 features -> Auc = 0.7801
# 251 features -> Auc = 0.7801
# 250 features -> Auc = 0.7802
# 249 features -> Auc = 0.7802
# 248 features -> Auc = 0.7802
# 247 features -> Auc = 0.7802
# 246 features -> Auc = 0.7801
# 245 features -> Auc = 0.7801
# 244 features -> Auc = 0.7800
# 243 features -> Auc = 0.7802
# 242 features -> Auc = 0.7803
# 241 features -> Auc = 0.7801
# 240 features -> Auc = 0.7801
# 239 features -> Auc = 0.7800
# 238 features -> Auc = 0.7799
# 237 features -> Auc = 0.7801
# 236 features -> Auc = 0.7802
# 235 features -> Auc = 0.7800
# 234 features -> Auc = 0.7802
# 233 features -> Auc = 0.7803
# 232 features -> Auc = 0.7801
# 231 features -> Auc = 0.7799
# 230 features -> Auc = 0.7799
# 229 features -> Auc = 0.7796
# 228 features -> Auc = 0.7797
# 227 features -> Auc = 0.7798
# 226 features -> Auc = 0.7797
# 225 features -> Auc = 0.7799
# 224 features -> Auc = 0.7801
# 223 features -> Auc = 0.7801
# 222 features -> Auc = 0.7800
# 221 features -> Auc = 0.7800
# 220 features -> Auc = 0.7799
# 219 features -> Auc = 0.7798
# 218 features -> Auc = 0.7798
# 217 features -> Auc = 0.7798
# 216 features -> Auc = 0.7804
# 215 features -> Auc = 0.7801
# 214 features -> Auc = 0.7803
# 213 features -> Auc = 0.7806
# 212 features -> Auc = 0.7798
# 211 features -> Auc = 0.7796
# 210 features -> Auc = 0.7798
# 209 features -> Auc = 0.7797
# 208 features -> Auc = 0.7797
# 207 features -> Auc = 0.7797
# 206 features -> Auc = 0.7795
# 205 features -> Auc = 0.7795
# 204 features -> Auc = 0.7795
# 203 features -> Auc = 0.7797
# 202 features -> Auc = 0.7798
# 201 features -> Auc = 0.7795
# 200 features -> Auc = 0.7793
# 199 features -> Auc = 0.7796
# 198 features -> Auc = 0.7795
# 197 features -> Auc = 0.7796
# 196 features -> Auc = 0.7798
# 195 features -> Auc = 0.7796
# 194 features -> Auc = 0.7797
# 193 features -> Auc = 0.7794
# 192 features -> Auc = 0.7798
# 191 features -> Auc = 0.7796
# 190 features -> Auc = 0.7797
# 189 features -> Auc = 0.7797
# 188 features -> Auc = 0.7799
# 187 features -> Auc = 0.7800
# 186 features -> Auc = 0.7800
# 185 features -> Auc = 0.7799
# 184 features -> Auc = 0.7804
# 183 features -> Auc = 0.7800
# 182 features -> Auc = 0.7799
# 181 features -> Auc = 0.7798
# 180 features -> Auc = 0.7795
# 179 features -> Auc = 0.7796
# 178 features -> Auc = 0.7800
# 177 features -> Auc = 0.7797
# 176 features -> Auc = 0.7793
# 175 features -> Auc = 0.7801
# 174 features -> Auc = 0.7802
# 173 features -> Auc = 0.7803
# 172 features -> Auc = 0.7800
# 171 features -> Auc = 0.7800
# 170 features -> Auc = 0.7802
# 169 features -> Auc = 0.7800
# 168 features -> Auc = 0.7801
# 167 features -> Auc = 0.7801
# 166 features -> Auc = 0.7803
# 165 features -> Auc = 0.7800
# 164 features -> Auc = 0.7797
# 163 features -> Auc = 0.7803
# 162 features -> Auc = 0.7794
# 161 features -> Auc = 0.7794
# 160 features -> Auc = 0.7800
# 159 features -> Auc = 0.7796
# 158 features -> Auc = 0.7795
# 157 features -> Auc = 0.7795
# 156 features -> Auc = 0.7795
# 155 features -> Auc = 0.7799
# 154 features -> Auc = 0.7796
# 153 features -> Auc = 0.7795
# 152 features -> Auc = 0.7797
# 151 features -> Auc = 0.7801
# 150 features -> Auc = 0.7799
# 149 features -> Auc = 0.7800
# 148 features -> Auc = 0.7802
# 147 features -> Auc = 0.7798
# 146 features -> Auc = 0.7797
# 145 features -> Auc = 0.7802
# 144 features -> Auc = 0.7797
# 143 features -> Auc = 0.7799
# 142 features -> Auc = 0.7795
# 141 features -> Auc = 0.7796
# 140 features -> Auc = 0.7798
# 139 features -> Auc = 0.7797
# 138 features -> Auc = 0.7799
# 137 features -> Auc = 0.7795
# 136 features -> Auc = 0.7792
# 135 features -> Auc = 0.7795
# 134 features -> Auc = 0.7794
# 133 features -> Auc = 0.7793
# 132 features -> Auc = 0.7796
# 131 features -> Auc = 0.7795
# 130 features -> Auc = 0.7794
# 129 features -> Auc = 0.7801
# 128 features -> Auc = 0.7794
# 127 features -> Auc = 0.7795
# 126 features -> Auc = 0.7796
# 125 features -> Auc = 0.7796
# 124 features -> Auc = 0.7797
# 123 features -> Auc = 0.7800
# 122 features -> Auc = 0.7794
# 121 features -> Auc = 0.7793
# 120 features -> Auc = 0.7792
# 119 features -> Auc = 0.7798
# 118 features -> Auc = 0.7791
# 117 features -> Auc = 0.7795
# 116 features -> Auc = 0.7796
# 115 features -> Auc = 0.7798
# 114 features -> Auc = 0.7799
# 113 features -> Auc = 0.7799
# 112 features -> Auc = 0.7801
# 111 features -> Auc = 0.7792
# 110 features -> Auc = 0.7798
# 109 features -> Auc = 0.7800
# 108 features -> Auc = 0.7796
# 107 features -> Auc = 0.7792
# 106 features -> Auc = 0.7794
# 105 features -> Auc = 0.7794
# 104 features -> Auc = 0.7791
# 103 features -> Auc = 0.7791
# 102 features -> Auc = 0.7793
# 101 features -> Auc = 0.7789
# 100 features -> Auc = 0.7791
# 99 features -> Auc = 0.7800
# 98 features -> Auc = 0.7794
# 97 features -> Auc = 0.7796
# 96 features -> Auc = 0.7795
# 95 features -> Auc = 0.7797
# 94 features -> Auc = 0.7794
# 93 features -> Auc = 0.7799
# 92 features -> Auc = 0.7801
# 91 features -> Auc = 0.7797
# 90 features -> Auc = 0.7799
# 89 features -> Auc = 0.7794
# 88 features -> Auc = 0.7798
# 87 features -> Auc = 0.7801
# 86 features -> Auc = 0.7795
# 85 features -> Auc = 0.7795
# 84 features -> Auc = 0.7796
# 83 features -> Auc = 0.7797
# 82 features -> Auc = 0.7789
# 81 features -> Auc = 0.7792
# 80 features -> Auc = 0.7789
# 79 features -> Auc = 0.7792
# 78 features -> Auc = 0.7790
# 77 features -> Auc = 0.7794
# 76 features -> Auc = 0.7789
# 75 features -> Auc = 0.7788
# 74 features -> Auc = 0.7786
# 73 features -> Auc = 0.7785
# 72 features -> Auc = 0.7783
# 71 features -> Auc = 0.7781
# 70 features -> Auc = 0.7782
# 69 features -> Auc = 0.7783
# 68 features -> Auc = 0.7783
# 67 features -> Auc = 0.7781
# 66 features -> Auc = 0.7775
# 65 features -> Auc = 0.7780
# 64 features -> Auc = 0.7768
# 63 features -> Auc = 0.7773
# 62 features -> Auc = 0.7770
# 61 features -> Auc = 0.7764
# 60 features -> Auc = 0.7764
# 59 features -> Auc = 0.7765
# 58 features -> Auc = 0.7757
# 57 features -> Auc = 0.7762
# 56 features -> Auc = 0.7765
# 55 features -> Auc = 0.7762
# 54 features -> Auc = 0.7764
# 53 features -> Auc = 0.7761
# 52 features -> Auc = 0.7740
# 51 features -> Auc = 0.7745
# 50 features -> Auc = 0.7744
# 49 features -> Auc = 0.7745
# 48 features -> Auc = 0.7744
# 47 features -> Auc = 0.7749
# 46 features -> Auc = 0.7749
# 45 features -> Auc = 0.7743
# 44 features -> Auc = 0.7743
# 43 features -> Auc = 0.7739
# 42 features -> Auc = 0.7744
# 41 features -> Auc = 0.7743
# 40 features -> Auc = 0.7730
# 39 features -> Auc = 0.7736
# 38 features -> Auc = 0.7731
# 37 features -> Auc = 0.7733
# 36 features -> Auc = 0.7726
# 35 features -> Auc = 0.7728
# 34 features -> Auc = 0.7732
# 33 features -> Auc = 0.7730
# 32 features -> Auc = 0.7726
# 31 features -> Auc = 0.7726
# 30 features -> Auc = 0.7726
# 29 features -> Auc = 0.7720
# 28 features -> Auc = 0.7716
# 27 features -> Auc = 0.7718
# 26 features -> Auc = 0.7721
# 25 features -> Auc = 0.7720
# 24 features -> Auc = 0.7714
# 23 features -> Auc = 0.7706
# 22 features -> Auc = 0.7707
# 21 features -> Auc = 0.7699
# 20 features -> Auc = 0.7697
# 19 features -> Auc = 0.7688
# 18 features -> Auc = 0.7686
# 17 features -> Auc = 0.7646
# 16 features -> Auc = 0.7652
# 15 features -> Auc = 0.7609
# 14 features -> Auc = 0.7612
# 13 features -> Auc = 0.7605
# 12 features -> Auc = 0.7599
# 11 features -> Auc = 0.7578
# 10 features -> Auc = 0.7559
# 9 features -> Auc = 0.7541
# 8 features -> Auc = 0.7532
# 7 features -> Auc = 0.7523
# 6 features -> Auc = 0.7507
# 5 features -> Auc = 0.7493
# 4 features -> Auc = 0.7422
#
# Durée (hh:mm:ss) : 1:23:00

# %%
print(f"{len(selector_lightgbm.best_features)} features ont été sélectionnées :")
print(selector_lightgbm.best_features)
print("Meilleur score de validation (AUC) :", selector_lightgbm.best_score)
# Out:
# 269 features ont été sélectionnées :
# ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_ANNUITY', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_CITY_NOT_LIVE_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'BASEMENTAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'YEARS_BEGINEXPLUATATION_MODE', 'LIVINGAREA_MODE', 'LANDAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_18', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR', 'CREDIT_TO_ANNUITY_RATIO', 'CREDIT_TO_GOODS_RATIO', 'ANNUITY_TO_INCOME_RATIO', 'INCOME_TO_BIRTH_RATIO', 'NAME_CONTRACT_TYPE_Revolvingloans', 'NAME_INCOME_TYPE_Commercialassociate', 'NAME_INCOME_TYPE_Stateservant', 'NAME_EDUCATION_TYPE_Highereducation', 'NAME_EDUCATION_TYPE_Incompletehigher', 'NAME_FAMILY_STATUS_Married', 'NAME_FAMILY_STATUS_Singlenotmarried', 'NAME_HOUSING_TYPE_Municipalapartment', 'NAME_HOUSING_TYPE_Officeapartment', 'OCCUPATION_TYPE_Corestaff', 'OCCUPATION_TYPE_Drivers', 'OCCUPATION_TYPE_Highskilltechstaff', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Managers', 'OCCUPATION_TYPE_Medicinestaff', 'OCCUPATION_TYPE_Privateservicestaff', 'OCCUPATION_TYPE_NA', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WEEKDAY_APPR_PROCESS_START_SATURDAY', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'ORGANIZATION_TYPE_Bank', 'ORGANIZATION_TYPE_Construction', 'ORGANIZATION_TYPE_Government', 'ORGANIZATION_TYPE_Industrytype7', 'ORGANIZATION_TYPE_Industrytype9', 'ORGANIZATION_TYPE_Kindergarten', 'ORGANIZATION_TYPE_Military', 'ORGANIZATION_TYPE_Police', 'ORGANIZATION_TYPE_Realtor', 'ORGANIZATION_TYPE_School', 'ORGANIZATION_TYPE_SecurityMinistries', 'ORGANIZATION_TYPE_Selfemployed', 'ORGANIZATION_TYPE_Tradetype7', 'ORGANIZATION_TYPE_Transporttype3', 'FONDKAPREMONT_MODE_regoperaccount', 'FONDKAPREMONT_MODE_regoperspecaccount', 'WALLSMATERIAL_MODE_Panel', 'WALLSMATERIAL_MODE_Stonebrick', 'BURO_DAYS_CREDIT_MIN', 'BURO_DAYS_CREDIT_MAX', 'BURO_DAYS_CREDIT_VAR', 'BURO_DAYS_CREDIT_ENDDATE_MIN', 'BURO_DAYS_CREDIT_ENDDATE_MEAN', 'BURO_CREDIT_DAY_OVERDUE_MAX', 'BURO_AMT_CREDIT_SUM_MAX', 'BURO_AMT_CREDIT_SUM_DEBT_MAX', 'BURO_AMT_CREDIT_SUM_DEBT_MEAN', 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN', 'BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'BURO_AMT_CREDIT_SUM_LIMIT_SUM', 'BURO_MONTHS_BALANCE_SIZE_MEAN', 'BURO_MONTHS_BALANCE_SIZE_SUM', 'BURO_CREDIT_ACTIVE_Active_MEAN', 'BURO_CREDIT_ACTIVE_Sold_MEAN', 'BURO_CREDIT_TYPE_Anothertypeofloan_MEAN', 'BURO_CREDIT_TYPE_Carloan_MEAN', 'BURO_CREDIT_TYPE_Creditcard_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'BURO_STATUS_0_MEAN_MEAN', 'BURO_STATUS_X_MEAN_MEAN', 'ACTIVE_DAYS_CREDIT_MIN', 'ACTIVE_DAYS_CREDIT_MAX', 'ACTIVE_DAYS_CREDIT_VAR', 'ACTIVE_DAYS_CREDIT_ENDDATE_MIN', 'ACTIVE_DAYS_CREDIT_ENDDATE_MAX', 'ACTIVE_DAYS_CREDIT_UPDATE_MEAN', 'ACTIVE_CREDIT_DAY_OVERDUE_MEAN', 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN', 'ACTIVE_AMT_CREDIT_SUM_MEAN', 'ACTIVE_AMT_CREDIT_SUM_SUM', 'ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'ACTIVE_CNT_CREDIT_PROLONG_SUM', 'ACTIVE_MONTHS_BALANCE_SIZE_MEAN', 'CLOSED_DAYS_CREDIT_MIN', 'CLOSED_DAYS_CREDIT_MAX', 'CLOSED_DAYS_CREDIT_VAR', 'CLOSED_DAYS_CREDIT_ENDDATE_MIN', 'CLOSED_DAYS_CREDIT_ENDDATE_MAX', 'CLOSED_DAYS_CREDIT_ENDDATE_MEAN', 'CLOSED_DAYS_CREDIT_UPDATE_MEAN', 'CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN', 'CLOSED_AMT_CREDIT_SUM_MEAN', 'CLOSED_AMT_CREDIT_SUM_SUM', 'CLOSED_AMT_CREDIT_SUM_DEBT_MAX', 'CLOSED_AMT_CREDIT_SUM_DEBT_MEAN', 'PREV_AMT_ANNUITY_MIN', 'PREV_AMT_CREDIT_MIN', 'PREV_AMT_CREDIT_MAX', 'PREV_APP_CREDIT_PERC_MIN', 'PREV_APP_CREDIT_PERC_MAX', 'PREV_APP_CREDIT_PERC_MEAN', 'PREV_APP_CREDIT_PERC ...
# Meilleur score de validation (AUC) : 0.7806667567520555

# %%
selector_lightgbm.plot_scores(y_lim=[0.74, 0.82], model_name="LightGBM")

# %%
selector_lightgbm.best_score
# Out:
# 0.7806667567520555

# %%
len(selector_lightgbm.best_features)
# Out:
# 269

# %%
selector_lightgbm.get_history(n_features_start=80, n_features_end=100)
# Out:
#      iteration  n_features       auc  \
# 332        333          92  0.780115
# 337        338          87  0.780059
# 325        326          99  0.780002
# 331        332          93  0.779937
# 334        335          90  0.779891
# 336        337          88  0.779816
# 341        342          83  0.779690
# 329        330          95  0.779674
# 333        334          91  0.779670
# 340        341          84  0.779591
# 327        328          97  0.779577
# 328        329          96  0.779522
# 339        340          85  0.779507
# 338        339          86  0.779468
# 326        327          98  0.779407
# 330        331          94  0.779403
# 335        336          89  0.779388
# 343        344          81  0.779192
# 324        325         100  0.779079
# 344        345          80  0.778942
# 342        343          82  0.778888
#
#                                                                                                                                                                                                                                                                                                                                                                                                             features
# 332  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 337  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_T...
# 325  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 331  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 334  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 336  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_T...
# 341  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_TO_BIRTH_RATIO, NA...
# 329  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 333  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 340  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_TO_BIRTH_RATIO, NA...
# 327  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 328  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 339  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_T...
# 338  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_T...
# 326  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 330  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 335  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 343  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_TO_BIRTH_RATIO, NA...
# 324  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, LIVINGAREA_MODE, LANDAREA_MEDI, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_...
# 344  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_TO_BIRTH_RATIO, NA...
# 342  [CODE_GENDER, AMT_ANNUITY, REGION_POPULATION_RELATIVE, DAYS_BIRTH, DAYS_EMPLOYED, DAYS_REGISTRATION, DAYS_ID_PUBLISH, OWN_CAR_AGE, REGION_RATING_CLIENT_W_CITY, EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3, YEARS_BEGINEXPLUATATION_MODE, TOTALAREA_MODE, DEF_30_CNT_SOCIAL_CIRCLE, DAYS_LAST_PHONE_CHANGE, CREDIT_TO_ANNUITY_RATIO, CREDIT_TO_GOODS_RATIO, ANNUITY_TO_INCOME_RATIO, INCOME_TO_BIRTH_RATIO, NA...

# %%
features = selector_lightgbm.best_features
X, y = read_train(features=features)
gc.collect()
cp._default_memory_pool.free_all_blocks()
model = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

eval = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)

eval.evaluate(X, y)
_ = eval.get_business_gain()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 features = selector_lightgbm.best_features
#       2 X, y = read_train(features=features)
#       3 gc.collect()
#
# NameError: name 'selector_lightgbm' is not defined

# %%
best_features = selector_lightgbm.get_features()
features_92 = selector_lightgbm.get_features(n_features=92)
features_87 = selector_lightgbm.get_features(n_features=87)

# %%
train = cudf.read_csv(os.path.join(DATA_CLEAN_DIR, "01_v2_vif_train.csv"))
train = reduce_memory_cudf(train).to_pandas()
y = train["TARGET"]

cmp_rfecv = ComparativeTable("Comparatif Nombre de features")
cmp_rfecv.set_duration_format({"fit_time": "{:.1f}"})
cmp_rfecv.set_column_order(
    [
        "model_name",
        "balancing",
        "business_gain",
        "auc",
        "accuracy",
        "recall",
        "f1_score",
        "fit_time",
        "fn",
        "n_feat.",
    ]
)

for features in [best_features, features_92, features_87]:
    X = train[features]
    model = LGBMClassifier(
        class_weight="balanced",
        n_threads=14,
        objective="binary",
        random_state=VAL_SEED,
        verbosity=-1,  # Pour ne pas voir les logs
    )

    eval = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)

    eval.evaluate(X, y)
    _ = eval.get_business_gain()
    cmp_rfecv.add(eval)
# Out:
# Memory usage of dataframe is 532.18 MB
# Memory usage after optimization is: 302.55 MB
# Decreased by 43.1%
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:18
# Business gain Train : 0.7601,	Business gain Validation : 0.7094
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:10
# Business gain Train : 0.7576,	Business gain Validation : 0.7103
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:10
# Business gain Train : 0.7571,	Business gain Validation : 0.7105

# %%
cmp_rfecv.display()
# Out:
# Comparatif Nombre de features
#        model_name              balancing business_gain     auc accuracy  \
# 0  LGBMClassifier  class_weight=balanced        0.7094  0.7807   0.7335
# 1  LGBMClassifier  class_weight=balanced        0.7103  0.7801   0.7327
# 2  LGBMClassifier  class_weight=balanced        0.7105  0.7801   0.7319
#
#    recall f1_score fit_time         fn  n_feat.
# 0  0.6795   0.2917      2.7  1194.2000      269
# 1  0.6825   0.2921      1.3  1183.0000       92
# 2  0.6839   0.2918      1.2  1177.8000       87

# %%
selector_lightgbm.best_score
# Out:
# 0.7806667567520555

# %% [markdown]
# ### Sauvegarde

# %%
save_pkl(selector_lightgbm.best_features, "features_rfecv_lightgbm_best")
save_pkl(features_87, "features_rfecv_lightgbm")
# Out:
# Liste des features (Nb = 269) engistrée dans models/features_rfecv_lightgbm_best.pkl
# Liste des features (Nb = 87) engistrée dans models/features_rfecv_lightgbm.pkl

# %%
train = cudf.read_csv(os.path.join(DATA_CLEAN_DIR, "01_v2_vif_train.csv"))
train_lightgbm = train[["SK_ID_CURR", "TARGET"] + features_87]

filepath = os.path.join(DATA_CLEAN_DIR, "01_v3_rfecv_lightgbm_train.csv")
train_lightgbm.to_csv(filepath, index=False)
print(f"Train pour lightgbm enregistré dans {filepath}")
# Out:
# Train pour lightgbm enregistré dans data/cleaned/01_v3_rfecv_lightgbm_train.csv

# %% [markdown]
# # Evaluation en validation croisée des modèles sur le nombre de features optimal

# %% [markdown]
# ## Création de l'expérience mlflow

# %%
_ = start_mlflow_ui()
# Out:
# L'interface web mlflow est disponible à l'adresse http://127.0.0.1:5000

# %%
exp_evaluation_id = create_or_load_experiment(
    name="eval_models",
    description="Evaluation des modèles en validation croisée sur le nombre optimal de features",
)
# Out:
# Création de l'expérience MLFlow 'eval_models', ID = 215726472202759917

# %% [markdown]
# ## Régression logistique sur le nombre de features optimal RFECV

# %% [markdown]
# #### Données

# %%
# Pour enregistrer les modèles avec signature, on cast proprement les données
features = read_pkl("features_rfecv_logreg")
print()
X, y = read_train(features=features, clean_dtype=True)
# Out:
# Objet list lu dans models/features_rfecv_logreg.pkl
#
# Memory usage of dataframe is 137.31 MB
# Memory usage after optimization is: 81.00 MB
# Decreased by 41.0%
# Cast des features
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Columns: 103 entries, CODE_GENDER to CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# dtypes: float32(58), float64(13), int64(32)
# memory usage: 132.0 MB

# %% [markdown]
# #### Exécution

# %%
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LogisticRegression(solver="lbfgs", n_jobs=14, max_iter=1000),
        ),
    ]
)

evaluator7 = EvaluatorCV(pipe=pipe, device="cpu", cv=5, random_state=VAL_SEED)
run_name = "logreg_smote_not_optim"
run_tags = {"balancing": evaluator7.balance_str, "optim": "Non"}
run_description = "LogReg SMOTE features RFECV Hyperparamètres non optimisés"
with mlflow.start_run(
    experiment_id=exp_evaluation_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator7.evaluate(X, y)
    _ = evaluator7.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:16
# Business gain Train : 0.6995,	Business gain Validation : 0.6990

# %% [markdown]
# #### Traçage des scores et des paramètres du modèle dans mlflow

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator7.get_mean_val_scores(prefix="val_")
    train_scores = evaluator7.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = evaluator7.get_model_params()
    # Finalement on s'aperçoit que loguer les paramètres du business_gain et le threshold_prob utilisé dans les params,
    # même en les préfixant, n'est pas du tout pratique (peu lisible).
    # Donc on logue uniquement les paramètres du modèle dans params et
    # on loguera le reste (business gain et threshold_prob) dans les artifacts.
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator7.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_evaluation_scores")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator7.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_confusion_matrix")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator7.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_roc_curve")

# %% [markdown]
# ### Loguer les features

# %%
"""
On ne logue pas le dataset car cela nous obligerait à l'enregistrer sur disque
On logue la liste des features utilisées sous forme de json dans les artifacts.
"""

# %%
with mlflow.start_run(run_id=run_id):
    log_features(X)

# %% [markdown]
# ### Loguer les paramètres du business_gain et le threshold_prob utilisé

# %%
with mlflow.start_run(run_id=run_id):
    bg_params = evaluator7.get_bg_params()
    threshold_prob = evaluator7.threshold_prob
    log_scoring_params(bg_params, threshold_prob)

# %% [markdown]
# ### Loguer le modèle RegLog

# %%
"""
Pour loguer le modèle dans mlflow, il doit être fitté. Or celui-ci est fitté uniquement sur le dernier fold.
Donc on le réentraîne sur le train entier.
"""
# Out:
# "\nPour loguer le modèle dans mlflow, il doit être fitté. Or celui-ci est fitté uniquement sur le dernier fold.\nDonc on le réentraîne sur le train entier.\nOn ne le versionne pas car il est encore en cours de développement, nous devons encore l'optimiser.\nNous relisons le train car celui-ci n'est pas optimisé et ne contient pas d'int en taille inférieur à int64 avec des NaN.\nEn effet les pandas DataFrame n'autorisent pas les NaN dans les int à moins qu'il s'agisse de Int64\n"

# %%
pipe.fit(X, y)

with mlflow.start_run(run_id=run_id):
    # On logue le modèle (il aparaîtra dans la colonne modèle de l'interface web mlflow)
    mlflow.sklearn.log_model(pipe, artifact_path="model")

    # On enregistre le modèle dans le Model Registry
    # A ce stade, notre modèle n'étant pas encore optimisé, il n'est pas destiné à être évalué avant de
    # passer en production. Autrement dit on ne fait pas de promotion du modèle.
    # On place donc le stage à None
    model_uri = f"runs:/{run.info.run_id}/model"
    registered_model = mlflow.register_model(model_uri, name="LogReg")
    print(
        f"Modèle enregistré avec le nom : {registered_model.name}, et la version : {registered_model.version}"
    )
# Out:
# Successfully registered model 'LogReg'.
# 2025/05/30 12:40:56 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: LogReg, version 1
# Modèle enregistré avec le nom : LogReg, et la version : 1
# Created version '1' of model 'LogReg'.

# %% [markdown]
# ## LightGBM sur le nombre de features optimal RFECV

# %% [markdown]
# #### Données

# %%
features = read_pkl("features_rfecv_lightgbm")
# Out:
# Objet list lu dans models/features_rfecv_lightgbm.pkl

# %%
X, y = read_train(features=features, clean_dtype=True)
# Out:
# Memory usage of dataframe is 155.67 MB
# Memory usage after optimization is: 92.33 MB
# Decreased by 40.7%
# Cast des features
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Data columns (total 87 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   CODE_GENDER                            230634 non-null  float64
#  1   AMT_ANNUITY                            230626 non-null  float32
#  2   REGION_POPULATION_RELATIVE             230634 non-null  float32
#  3   DAYS_BIRTH                             230634 non-null  float64
#  4   DAYS_EMPLOYED                          189075 non-null  float32
#  5   DAYS_REGISTRATION                      230634 non-null  float32
#  6   DAYS_ID_PUBLISH                        230634 non-null  float64
#  7   OWN_CAR_AGE                            78227 non-null   float32
#  8   REGION_RATING_CLIENT_W_CITY            230634 non-null  float64
#  9   EXT_SOURCE_1                           100812 non-null  float32
#  10  EXT_SOURCE_2                           230153 non-null  float32
#  11  EXT_SOURCE_3                           184930 non-null  float32
#  12  YEARS_BEGINEXPLUATATION_MODE           117976 non-null  float32
#  13  LIVINGAREA_MODE                        114683 non-null  float32
#  14  TOTALAREA_MODE                         119183 non-null  float32
#  15  DEF_30_CNT_SOCIAL_CIRCLE               229845 non-null  float32
#  16  DAYS_LAST_PHONE_CHANGE                 230633 non-null  float32
#  17  CREDIT_TO_ANNUITY_RATIO                230626 non-null  float32
#  18  CREDIT_TO_GOODS_RATIO                  230431 non-null  float32
#  19  ANNUITY_TO_INCOME_RATIO                230626 non-null  float32
#  20  INCOME_TO_BIRTH_RATIO                  230634 non-null  float32
#  21  NAME_EDUCATION_TYPE_Highereducation    230634 non-null  int64
#  22  NAME_FAMILY_STATUS_Married             230634 non-null  int64
#  23  BURO_DAYS_CREDIT_MAX                   197711 non-null  float64
#  24  BURO_DAYS_CREDIT_ENDDATE_MEAN          196021 non-null  float32
#  25  BURO_AMT_CREDIT_SUM_MAX                197710 non-null  float32
#  26  BURO_AMT_CREDIT_SUM_DEBT_MEAN          192198 non-null  float64
#  27  BURO_CREDIT_ACTIVE_Active_MEAN         197711 non-null  float32
#  28  BURO_CREDIT_TYPE_Microloan_MEAN        197711 non-null  float32
#  29  BURO_CREDIT_TYPE_Mortgage_MEAN         197711 non-null  float32
#  30  BURO_STATUS_0_MEAN_MEAN                69121 non-null   float32
#  31  ACTIVE_DAYS_CREDIT_MAX                 162938 non-null  float64
#  32  ACTIVE_DAYS_CREDIT_ENDDATE_MIN         156232 non-null  float32
#  33  ACTIVE_DAYS_CREDIT_ENDDATE_MAX         156232 non-null  float32
#  34  ACTIVE_DAYS_CREDIT_UPDATE_MEAN         162938 non-null  float32
#  35  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN     87201 non-null   float32
#  36  ACTIVE_AMT_CREDIT_SUM_MEAN             162937 non-null  float32
#  37  ACTIVE_AMT_CREDIT_SUM_SUM              162937 non-null  float32
#  38  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN       141556 non-null  float64
#  39  ACTIVE_MONTHS_BALANCE_SIZE_MEAN        57362 non-null   float32
#  40  CLOSED_DAYS_CREDIT_MAX                 172754 non-null  float64
#  41  CLOSED_DAYS_CREDIT_VAR                 132596 non-null  float32
#  42  CLOSED_DAYS_CREDIT_ENDDATE_MAX         171624 non-null  float32
#  43  CLOSED_DAYS_CREDIT_UPDATE_MEAN         172754 non-null  float32
#  44  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN     110007 non-null  float32
#  45  CLOSED_AMT_CREDIT_SUM_MEAN             172754 non-null  float32
#  46  CLOSED_AMT_CREDIT_SUM_SUM              172754 non-null  float32
#  47  PREV_AMT_ANNUITY_MIN                   218039 non-null  float32
#  48  PREV_APP_CREDIT_PERC_MAX               189380 non-null  float32
#  49  PREV_AMT_GOODS_PRICE_MIN               217620 non-null  float32
#  50  PREV_HOUR_APPR_PROCESS_START_MAX       218343 non-null  float64
#  51  PREV_DAYS_DECISION_MIN                 218343 non-null  float64
#  52  PREV_DAYS_DECISION_MAX                 218343 non-null  float64
#  53  PREV_CNT_PAYMENT_SUM                   218040 non-null  float32
#  54  PREV_NAME_YIELD_GROUP_low_action_MEAN  218343 non-null  float32
#  55  APPROVED_AMT_ANNUITY_MAX               217617 non-null  float32
#  56  APPROVED_APP_CREDIT_PERC_MIN           217382 non-null  float32
#  57  APPROVED_APP_CREDIT_PERC_MAX           217382 non-null  float32
#  58  APPROVED_AMT_DOWN_PAYMENT_MAX          203521 non-null  float32
#  59  APPROVED_AMT_GOODS_PRICE_MAX           216884 non-null  float32
#  60  APPROVED_DAYS_DECISION_MAX             217618 non-null  float64
#  61  APPROVED_CNT_PAYMENT_MEAN              217618 non-null  float32
#  62  REFUSED_AMT_CREDIT_MIN                 75233 non-null   float32
#  63  REFUSED_APP_CREDIT_PERC_MIN            69100 non-null   float32
#  64  REFUSED_DAYS_DECISION_MAX              75233 non-null   float64
#  65  POS_MONTHS_BALANCE_MEAN                217199 non-null  float32
#  66  POS_SK_DPD_DEF_MEAN                    217199 non-null  float32
#  67  POS_COUNT                              217199 non-null  float64
#  68  INSTAL_DPD_MEAN                        218815 non-null  float32
#  69  INSTAL_DBD_MEAN                        218815 non-null  float32
#  70  INSTAL_DBD_SUM                         218815 non-null  float32
#  71  INSTAL_PAYMENT_PERC_MEAN               218800 non-null  float32
#  72  INSTAL_PAYMENT_PERC_SUM                218800 non-null  float32
#  73  INSTAL_PAYMENT_DIFF_MAX                218815 non-null  float32
#  74  INSTAL_PAYMENT_DIFF_MEAN               218815 non-null  float64
#  75  INSTAL_PAYMENT_DIFF_SUM                218815 non-null  float64
#  76  INSTAL_AMT_INSTALMENT_MAX              218822 non-null  float32
#  77  INSTAL_AMT_INSTALMENT_MEAN             218822 non-null  float32
#  78  INSTAL_AMT_INSTALMENT_SUM              218822 non-null  float32
#  79  INSTAL_AMT_PAYMENT_MIN                 218815 non-null  float32
#  80  INSTAL_DAYS_ENTRY_PAYMENT_MAX          218815 non-null  float32
#  81  INSTAL_DAYS_ENTRY_PAYMENT_SUM          218815 non-null  float64
#  82  CC_AMT_BALANCE_MEAN                    64955 non-null   float32
#  83  CC_AMT_PAYMENT_CURRENT_SUM             45634 non-null   float32
#  84  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       45699 non-null   float32
#  85  CC_CNT_DRAWINGS_CURRENT_MEAN           64955 non-null   float32
#  86  CC_CNT_DRAWINGS_CURRENT_VAR            64485 non-null   float32
# dtypes: float32(67), float64(18), int64(2)
# memory usage: 95.9 MB

# %% [markdown]
# #### Exécution

# %%
model = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

evaluator8 = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)
run_name = "lightgbm_balanced_not_optim"
run_tags = {"balancing": evaluator8.balance_str, "optim": "Non"}
run_description = "LightGBM class_weight features RFECV Hyperparamètres non optimisés"

with mlflow.start_run(
    experiment_id=exp_evaluation_id,
    run_name=run_name,
    tags=run_tags,
    description=run_description,
) as run:
    run_id = run.info.run_id
    evaluator8.evaluate(X, y)
    _ = evaluator8.get_business_gain()
# Out:
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:09
# Business gain Train : 0.7524,	Business gain Validation : 0.7191

# %% [markdown]
# #### Traçage des scores et des paramètres dans mlflow

# %%
with mlflow.start_run(run_id=run_id):
    val_scores = evaluator8.get_mean_val_scores(prefix="val_")
    train_scores = evaluator8.get_mean_train_scores(prefix="train_")
    scores = {**train_scores, **val_scores}
    mlflow.log_metrics(scores)
    params = evaluator8.get_model_params()
    mlflow.log_params(params)

# %% [markdown]
# ### Plot Scores d'entraînement et de validation

# %%
fig = evaluator8.plot_evaluation_scores()

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_evaluation_scores")

# %% [markdown]
# ### Plot Matrice confusion

# %%
fig = evaluator8.plot_conf_mat()
fig

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_confusion_matrix")

# %% [markdown]
# ### Plot Roc Curve

# %%
fig = evaluator8.plot_roc_curve()

# %%
with mlflow.start_run(run_id=run_id):
    log_image(fig, "plot_roc_curve")

# %% [markdown]
# ### Log du modèle LightGBM

# %%
model.fit(X, y)
with mlflow.start_run(run_id=run_id):
    mlflow.sklearn.log_model(model, artifact_path="model")
    model_uri = f"runs:/{run.info.run_id}/model"
    registered_model = mlflow.register_model(model_uri, name="LightGBM")
    print(
        f"Modèle enregistré avec le nom : {registered_model.name}, et la version : {registered_model.version}"
    )
# Out:
# Successfully registered model 'LightGBM'.
# 2025/05/30 12:53:42 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: LightGBM, version 1
# Modèle enregistré avec le nom : LightGBM, et la version : 1
# Created version '1' of model 'LightGBM'.

# %% [markdown]
# ### Log des features LightGBM

# %%
with mlflow.start_run(run_id=run_id):
    log_features(X)

# %% [markdown]
# ### Log des paramètres de scoring LightGBM (Business_gain et threshold_prob)

# %% [markdown]
# ### Loguer les paramètres du business_gain et le threshold_prob utilisé

# %%
with mlflow.start_run(run_id=run_id):
    bg_params = evaluator8.get_bg_params()
    threshold_prob = evaluator8.threshold_prob
    log_scoring_params(bg_params, threshold_prob)

# %% [markdown]
# ## Conclusion des évaluations

# %%
"""features = read_pkl("features_rfecv_logreg")
X, y = read_train(features=features, clean_dtype=True)
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LogisticRegression(solver="lbfgs", n_jobs=14, max_iter=1000),
        ),
    ]
)

evaluator7 = EvaluatorCV(pipe=pipe, device="cpu", cv=5, random_state=VAL_SEED)
evaluator7.evaluate(X, y)"""
# Out:
# Objet list lu dans models/features_rfecv_logreg.pkl
# Memory usage of dataframe is 137.31 MB
# Memory usage after optimization is: 81.00 MB
# Decreased by 41.0%
# Cast des features
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Columns: 103 entries, CODE_GENDER to CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# dtypes: float32(58), float64(13), int64(32)
# memory usage: 132.0 MB
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:16

# %%
"""features = read_pkl("features_rfecv_lightgbm")
X, y = read_train(features=features, clean_dtype=True)
#### Exécution
model = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

evaluator8 = EvaluatorCV(pipe=model, device="cpu", cv=5, random_state=VAL_SEED)
evaluator8.evaluate(X, y)
_ = evaluator8.get_business_gain()"""
# Out:
# Objet list lu dans models/features_rfecv_lightgbm.pkl
# Memory usage of dataframe is 155.67 MB
# Memory usage after optimization is: 92.33 MB
# Decreased by 40.7%
# Cast des features
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Data columns (total 87 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   CODE_GENDER                            230634 non-null  float64
#  1   AMT_ANNUITY                            230626 non-null  float32
#  2   REGION_POPULATION_RELATIVE             230634 non-null  float32
#  3   DAYS_BIRTH                             230634 non-null  float64
#  4   DAYS_EMPLOYED                          189075 non-null  float32
#  5   DAYS_REGISTRATION                      230634 non-null  float32
#  6   DAYS_ID_PUBLISH                        230634 non-null  float64
#  7   OWN_CAR_AGE                            78227 non-null   float32
#  8   REGION_RATING_CLIENT_W_CITY            230634 non-null  float64
#  9   EXT_SOURCE_1                           100812 non-null  float32
#  10  EXT_SOURCE_2                           230153 non-null  float32
#  11  EXT_SOURCE_3                           184930 non-null  float32
#  12  YEARS_BEGINEXPLUATATION_MODE           117976 non-null  float32
#  13  LIVINGAREA_MODE                        114683 non-null  float32
#  14  TOTALAREA_MODE                         119183 non-null  float32
#  15  DEF_30_CNT_SOCIAL_CIRCLE               229845 non-null  float32
#  16  DAYS_LAST_PHONE_CHANGE                 230633 non-null  float32
#  17  CREDIT_TO_ANNUITY_RATIO                230626 non-null  float32
#  18  CREDIT_TO_GOODS_RATIO                  230431 non-null  float32
#  19  ANNUITY_TO_INCOME_RATIO                230626 non-null  float32
#  20  INCOME_TO_BIRTH_RATIO                  230634 non-null  float32
#  21  NAME_EDUCATION_TYPE_Highereducation    230634 non-null  int64
#  22  NAME_FAMILY_STATUS_Married             230634 non-null  int64
#  23  BURO_DAYS_CREDIT_MAX                   197711 non-null  float64
#  24  BURO_DAYS_CREDIT_ENDDATE_MEAN          196021 non-null  float32
#  25  BURO_AMT_CREDIT_SUM_MAX                197710 non-null  float32
#  26  BURO_AMT_CREDIT_SUM_DEBT_MEAN          192198 non-null  float64
#  27  BURO_CREDIT_ACTIVE_Active_MEAN         197711 non-null  float32
#  28  BURO_CREDIT_TYPE_Microloan_MEAN        197711 non-null  float32
#  29  BURO_CREDIT_TYPE_Mortgage_MEAN         197711 non-null  float32
#  30  BURO_STATUS_0_MEAN_MEAN                69121 non-null   float32
#  31  ACTIVE_DAYS_CREDIT_MAX                 162938 non-null  float64
#  32  ACTIVE_DAYS_CREDIT_ENDDATE_MIN         156232 non-null  float32
#  33  ACTIVE_DAYS_CREDIT_ENDDATE_MAX         156232 non-null  float32
#  34  ACTIVE_DAYS_CREDIT_UPDATE_MEAN         162938 non-null  float32
#  35  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN     87201 non-null   float32
#  36  ACTIVE_AMT_CREDIT_SUM_MEAN             162937 non-null  float32
#  37  ACTIVE_AMT_CREDIT_SUM_SUM              162937 non-null  float32
#  38  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN       141556 non-null  float64
#  39  ACTIVE_MONTHS_BALANCE_SIZE_MEAN        57362 non-null   float32
#  40  CLOSED_DAYS_CREDIT_MAX                 172754 non-null  float64
#  41  CLOSED_DAYS_CREDIT_VAR                 132596 non-null  float32
#  42  CLOSED_DAYS_CREDIT_ENDDATE_MAX         171624 non-null  float32
#  43  CLOSED_DAYS_CREDIT_UPDATE_MEAN         172754 non-null  float32
#  44  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN     110007 non-null  float32
#  45  CLOSED_AMT_CREDIT_SUM_MEAN             172754 non-null  float32
#  46  CLOSED_AMT_CREDIT_SUM_SUM              172754 non-null  float32
#  47  PREV_AMT_ANNUITY_MIN                   218039 non-null  float32
#  48  PREV_APP_CREDIT_PERC_MAX               189380 non-null  float32
#  49  PREV_AMT_GOODS_PRICE_MIN               217620 non-null  float32
#  50  PREV_HOUR_APPR_PROCESS_START_MAX       218343 non-null  float64
#  51  PREV_DAYS_DECISION_MIN                 218343 non-null  float64
#  52  PREV_DAYS_DECISION_MAX                 218343 non-null  float64
#  53  PREV_CNT_PAYMENT_SUM                   218040 non-null  float32
#  54  PREV_NAME_YIELD_GROUP_low_action_MEAN  218343 non-null  float32
#  55  APPROVED_AMT_ANNUITY_MAX               217617 non-null  float32
#  56  APPROVED_APP_CREDIT_PERC_MIN           217382 non-null  float32
#  57  APPROVED_APP_CREDIT_PERC_MAX           217382 non-null  float32
#  58  APPROVED_AMT_DOWN_PAYMENT_MAX          203521 non-null  float32
#  59  APPROVED_AMT_GOODS_PRICE_MAX           216884 non-null  float32
#  60  APPROVED_DAYS_DECISION_MAX             217618 non-null  float64
#  61  APPROVED_CNT_PAYMENT_MEAN              217618 non-null  float32
#  62  REFUSED_AMT_CREDIT_MIN                 75233 non-null   float32
#  63  REFUSED_APP_CREDIT_PERC_MIN            69100 non-null   float32
#  64  REFUSED_DAYS_DECISION_MAX              75233 non-null   float64
#  65  POS_MONTHS_BALANCE_MEAN                217199 non-null  float32
#  66  POS_SK_DPD_DEF_MEAN                    217199 non-null  float32
#  67  POS_COUNT                              217199 non-null  float64
#  68  INSTAL_DPD_MEAN                        218815 non-null  float32
#  69  INSTAL_DBD_MEAN                        218815 non-null  float32
#  70  INSTAL_DBD_SUM                         218815 non-null  float32
#  71  INSTAL_PAYMENT_PERC_MEAN               218800 non-null  float32
#  72  INSTAL_PAYMENT_PERC_SUM                218800 non-null  float32
#  73  INSTAL_PAYMENT_DIFF_MAX                218815 non-null  float32
#  74  INSTAL_PAYMENT_DIFF_MEAN               218815 non-null  float64
#  75  INSTAL_PAYMENT_DIFF_SUM                218815 non-null  float64
#  76  INSTAL_AMT_INSTALMENT_MAX              218822 non-null  float32
#  77  INSTAL_AMT_INSTALMENT_MEAN             218822 non-null  float32
#  78  INSTAL_AMT_INSTALMENT_SUM              218822 non-null  float32
#  79  INSTAL_AMT_PAYMENT_MIN                 218815 non-null  float32
#  80  INSTAL_DAYS_ENTRY_PAYMENT_MAX          218815 non-null  float32
#  81  INSTAL_DAYS_ENTRY_PAYMENT_SUM          218815 non-null  float64
#  82  CC_AMT_BALANCE_MEAN                    64955 non-null   float32
#  83  CC_AMT_PAYMENT_CURRENT_SUM             45634 non-null   float32
#  84  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       45699 non-null   float32
#  85  CC_CNT_DRAWINGS_CURRENT_MEAN           64955 non-null   float32
#  86  CC_CNT_DRAWINGS_CURRENT_VAR            64485 non-null   float32
# dtypes: float32(67), float64(18), int64(2)
# memory usage: 95.9 MB
# Durée de l'évaluation en validation croisée sur cpu (5 folds): 0:00:10
# Business gain Train : 0.7524,	Business gain Validation : 0.7191

# %%
cmp_eval = ComparativeTable("Comparatif Evaluation des modèles en validation croisée")
cmp_eval.set_duration_format({"fit_time": "{:.1f}"})
cmp_eval.set_column_order(
    [
        "model_name",
        "balancing",
        "business_gain",
        "auc",
        "accuracy",
        "recall",
        "f1_score",
        "fit_time",
        "fn",
        "n_feat.",
    ]
)
cmp_eval.add(evaluator7, tags={"description": "Avant optimisation"})
cmp_eval.add(evaluator8, tags={"description": "Avant optimisation"})
cmp_eval.display()
# Out:
# Comparatif Evaluation des modèles en validation croisée
#            model_name              balancing business_gain     auc accuracy  \
# 0  LogisticRegression                  SMOTE        0.6990  0.7565   0.7104
# 1      LGBMClassifier  class_weight=balanced        0.7191  0.7801   0.7319
#
#    recall f1_score fit_time         fn  n_feat.
# 0  0.6677   0.2714      2.4  1238.2000      103
# 1  0.6839   0.2918      1.2  1177.8000       87

# %%
cmp_eval.save(filename="cmp_eval_cv")
# Out:
# Tableau comparatif enregistré dans models/cmp_eval_cv.pkl

# %%
"""
L'évaluation en validation croisée des 2 modèles, chacun avec sa stratégie de rééquilibrage qui lui convient le mieux et
chacun sur ses features optimales,
montre que c'est le le modèle lightGBM qui est le plus performant
autant sur les metriques (business_gain, auc, recall) que sur le temps de fit.
"""

# %% [markdown]
# # Test des deux modèles sur notre jeu de test

# %%
"""
On teste les 2 modèles sur le jeu de test resté caché jusqu'à présent pour confirmer que nous ne sommes pas en surfit.
"""

# %% [markdown]
# ## Test - Régression logistique SMOTE features rfecv

# %%
from src.modeling.p7_evaluate import Evaluator
from src.modeling.p7_constantes import DATA_INTERIM

# %%
features = read_pkl("features_rfecv_logreg")
print()
X_train, y_train = read_train(features=features)
X_test, y_test = read_train(
    directory=DATA_INTERIM, train_name="01_v0_built_test.csv", features=features
)
pipe = ImblearnPipeline(
    [
        ("imputer", SimpleImputer()),
        ("scaler", StandardScaler()),
        ("smote", SMOTE(k_neighbors=5, n_jobs=14, random_state=VAL_SEED)),
        (
            "clf",
            LogisticRegression(solver="lbfgs", n_jobs=14, max_iter=1000),
        ),
    ]
)

testor1 = Evaluator(pipe=pipe, random_state=VAL_SEED)

testor1.evaluate(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
_ = testor1.get_business_gain()
val_scores = testor1.get_test_scores(prefix="test_")
train_scores = testor1.get_train_scores(prefix="train_")
scores = {**train_scores, **val_scores}
_ = testor1.plot_evaluation_scores()
# Out:
# Objet list lu dans models/features_rfecv_logreg.pkl
#
# Memory usage of dataframe is 137.31 MB
# Memory usage after optimization is: 81.00 MB
# Decreased by 41.0%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Columns: 103 entries, CODE_GENDER to CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# dtypes: bool(32), float32(58), float64(8), int32(3), int64(2)
# memory usage: 80.1 MB
# Memory usage of dataframe is 45.76 MB
# Memory usage after optimization is: 26.11 MB
# Decreased by 42.9%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 76877 entries, 209003 to 429566
# Columns: 103 entries, CODE_GENDER to CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# dtypes: bool(32), float32(63), float64(3), int32(3), int64(2)
# memory usage: 25.2 MB
# Durée de l'évaluation : 0:00:07
# Business gain Train : 0.6991,	Business gain Test : 0.6772

# %%
import matplotlib.pyplot as plt

fig = testor1.plot_conf_mat()
fig

# %% [markdown]
# ## Test - LightGBM Balanced features rfecv

# %%
features = read_pkl("features_rfecv_lightgbm")
print()
X_train, y_train = read_train(features=features)
X_test, y_test = read_train(
    directory=DATA_INTERIM, train_name="01_v0_built_test.csv", features=features
)

model = LGBMClassifier(
    class_weight="balanced",
    n_threads=14,
    objective="binary",
    random_state=VAL_SEED,
    verbosity=-1,  # Pour ne pas voir les logs
)

testor2 = Evaluator(pipe=model, random_state=VAL_SEED)

testor2.evaluate(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
_ = testor2.get_business_gain()
val_scores = testor2.get_test_scores(prefix="val_")
train_scores = testor2.get_train_scores(prefix="train_")
scores = {**train_scores, **val_scores}
_ = testor2.plot_evaluation_scores()
# Out:
# Objet list lu dans models/features_rfecv_lightgbm.pkl
#
# Memory usage of dataframe is 155.67 MB
# Memory usage after optimization is: 92.33 MB
# Decreased by 40.7%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 230634 entries, 127032 to 421871
# Data columns (total 87 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   CODE_GENDER                            230634 non-null  int32
#  1   AMT_ANNUITY                            230626 non-null  float32
#  2   REGION_POPULATION_RELATIVE             230634 non-null  float32
#  3   DAYS_BIRTH                             230634 non-null  int64
#  4   DAYS_EMPLOYED                          189075 non-null  float32
#  5   DAYS_REGISTRATION                      230634 non-null  float32
#  6   DAYS_ID_PUBLISH                        230634 non-null  int64
#  7   OWN_CAR_AGE                            78227 non-null   float32
#  8   REGION_RATING_CLIENT_W_CITY            230634 non-null  int32
#  9   EXT_SOURCE_1                           100812 non-null  float32
#  10  EXT_SOURCE_2                           230153 non-null  float32
#  11  EXT_SOURCE_3                           184930 non-null  float32
#  12  YEARS_BEGINEXPLUATATION_MODE           117976 non-null  float32
#  13  LIVINGAREA_MODE                        114683 non-null  float32
#  14  TOTALAREA_MODE                         119183 non-null  float32
#  15  DEF_30_CNT_SOCIAL_CIRCLE               229845 non-null  float32
#  16  DAYS_LAST_PHONE_CHANGE                 230633 non-null  float32
#  17  CREDIT_TO_ANNUITY_RATIO                230626 non-null  float32
#  18  CREDIT_TO_GOODS_RATIO                  230431 non-null  float32
#  19  ANNUITY_TO_INCOME_RATIO                230626 non-null  float32
#  20  INCOME_TO_BIRTH_RATIO                  230634 non-null  float32
#  21  NAME_EDUCATION_TYPE_Highereducation    230634 non-null  bool
#  22  NAME_FAMILY_STATUS_Married             230634 non-null  bool
#  23  BURO_DAYS_CREDIT_MAX                   197711 non-null  float64
#  24  BURO_DAYS_CREDIT_ENDDATE_MEAN          196021 non-null  float32
#  25  BURO_AMT_CREDIT_SUM_MAX                197710 non-null  float32
#  26  BURO_AMT_CREDIT_SUM_DEBT_MEAN          192198 non-null  float64
#  27  BURO_CREDIT_ACTIVE_Active_MEAN         197711 non-null  float32
#  28  BURO_CREDIT_TYPE_Microloan_MEAN        197711 non-null  float32
#  29  BURO_CREDIT_TYPE_Mortgage_MEAN         197711 non-null  float32
#  30  BURO_STATUS_0_MEAN_MEAN                69121 non-null   float32
#  31  ACTIVE_DAYS_CREDIT_MAX                 162938 non-null  float64
#  32  ACTIVE_DAYS_CREDIT_ENDDATE_MIN         156232 non-null  float32
#  33  ACTIVE_DAYS_CREDIT_ENDDATE_MAX         156232 non-null  float32
#  34  ACTIVE_DAYS_CREDIT_UPDATE_MEAN         162938 non-null  float32
#  35  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN     87201 non-null   float32
#  36  ACTIVE_AMT_CREDIT_SUM_MEAN             162937 non-null  float32
#  37  ACTIVE_AMT_CREDIT_SUM_SUM              162937 non-null  float32
#  38  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN       141556 non-null  float64
#  39  ACTIVE_MONTHS_BALANCE_SIZE_MEAN        57362 non-null   float32
#  40  CLOSED_DAYS_CREDIT_MAX                 172754 non-null  float64
#  41  CLOSED_DAYS_CREDIT_VAR                 132596 non-null  float32
#  42  CLOSED_DAYS_CREDIT_ENDDATE_MAX         171624 non-null  float32
#  43  CLOSED_DAYS_CREDIT_UPDATE_MEAN         172754 non-null  float32
#  44  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN     110007 non-null  float32
#  45  CLOSED_AMT_CREDIT_SUM_MEAN             172754 non-null  float32
#  46  CLOSED_AMT_CREDIT_SUM_SUM              172754 non-null  float32
#  47  PREV_AMT_ANNUITY_MIN                   218039 non-null  float32
#  48  PREV_APP_CREDIT_PERC_MAX               189380 non-null  float32
#  49  PREV_AMT_GOODS_PRICE_MIN               217620 non-null  float32
#  50  PREV_HOUR_APPR_PROCESS_START_MAX       218343 non-null  float64
#  51  PREV_DAYS_DECISION_MIN                 218343 non-null  float64
#  52  PREV_DAYS_DECISION_MAX                 218343 non-null  float64
#  53  PREV_CNT_PAYMENT_SUM                   218040 non-null  float32
#  54  PREV_NAME_YIELD_GROUP_low_action_MEAN  218343 non-null  float32
#  55  APPROVED_AMT_ANNUITY_MAX               217617 non-null  float32
#  56  APPROVED_APP_CREDIT_PERC_MIN           217382 non-null  float32
#  57  APPROVED_APP_CREDIT_PERC_MAX           217382 non-null  float32
#  58  APPROVED_AMT_DOWN_PAYMENT_MAX          203521 non-null  float32
#  59  APPROVED_AMT_GOODS_PRICE_MAX           216884 non-null  float32
#  60  APPROVED_DAYS_DECISION_MAX             217618 non-null  float64
#  61  APPROVED_CNT_PAYMENT_MEAN              217618 non-null  float32
#  62  REFUSED_AMT_CREDIT_MIN                 75233 non-null   float32
#  63  REFUSED_APP_CREDIT_PERC_MIN            69100 non-null   float32
#  64  REFUSED_DAYS_DECISION_MAX              75233 non-null   float64
#  65  POS_MONTHS_BALANCE_MEAN                217199 non-null  float32
#  66  POS_SK_DPD_DEF_MEAN                    217199 non-null  float32
#  67  POS_COUNT                              217199 non-null  float64
#  68  INSTAL_DPD_MEAN                        218815 non-null  float32
#  69  INSTAL_DBD_MEAN                        218815 non-null  float32
#  70  INSTAL_DBD_SUM                         218815 non-null  float32
#  71  INSTAL_PAYMENT_PERC_MEAN               218800 non-null  float32
#  72  INSTAL_PAYMENT_PERC_SUM                218800 non-null  float32
#  73  INSTAL_PAYMENT_DIFF_MAX                218815 non-null  float32
#  74  INSTAL_PAYMENT_DIFF_MEAN               218815 non-null  float64
#  75  INSTAL_PAYMENT_DIFF_SUM                218815 non-null  float64
#  76  INSTAL_AMT_INSTALMENT_MAX              218822 non-null  float32
#  77  INSTAL_AMT_INSTALMENT_MEAN             218822 non-null  float32
#  78  INSTAL_AMT_INSTALMENT_SUM              218822 non-null  float32
#  79  INSTAL_AMT_PAYMENT_MIN                 218815 non-null  float32
#  80  INSTAL_DAYS_ENTRY_PAYMENT_MAX          218815 non-null  float32
#  81  INSTAL_DAYS_ENTRY_PAYMENT_SUM          218815 non-null  float64
#  82  CC_AMT_BALANCE_MEAN                    64955 non-null   float32
#  83  CC_AMT_PAYMENT_CURRENT_SUM             45634 non-null   float32
#  84  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       45699 non-null   float32
#  85  CC_CNT_DRAWINGS_CURRENT_MEAN           64955 non-null   float32
#  86  CC_CNT_DRAWINGS_CURRENT_VAR            64485 non-null   float32
# dtypes: bool(2), float32(67), float64(14), int32(2), int64(2)
# memory usage: 91.1 MB
# Memory usage of dataframe is 51.88 MB
# Memory usage after optimization is: 28.72 MB
# Decreased by 44.7%
#
# Info X_train
# <class 'pandas.core.frame.DataFrame'>
# Index: 76877 entries, 209003 to 429566
# Data columns (total 87 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CODE_GENDER                            76877 non-null  int32
#  1   AMT_ANNUITY                            76873 non-null  float32
#  2   REGION_POPULATION_RELATIVE             76877 non-null  float32
#  3   DAYS_BIRTH                             76877 non-null  int64
#  4   DAYS_EMPLOYED                          63062 non-null  float32
#  5   DAYS_REGISTRATION                      76877 non-null  float32
#  6   DAYS_ID_PUBLISH                        76877 non-null  int64
#  7   OWN_CAR_AGE                            26355 non-null  float32
#  8   REGION_RATING_CLIENT_W_CITY            76877 non-null  int32
#  9   EXT_SOURCE_1                           33321 non-null  float32
#  10  EXT_SOURCE_2                           76698 non-null  float32
#  11  EXT_SOURCE_3                           61616 non-null  float32
#  12  YEARS_BEGINEXPLUATATION_MODE           39528 non-null  float32
#  13  LIVINGAREA_MODE                        38478 non-null  float32
#  14  TOTALAREA_MODE                         39897 non-null  float32
#  15  DEF_30_CNT_SOCIAL_CIRCLE               76645 non-null  float32
#  16  DAYS_LAST_PHONE_CHANGE                 76877 non-null  float32
#  17  CREDIT_TO_ANNUITY_RATIO                76873 non-null  float32
#  18  CREDIT_TO_GOODS_RATIO                  76802 non-null  float32
#  19  ANNUITY_TO_INCOME_RATIO                76873 non-null  float32
#  20  INCOME_TO_BIRTH_RATIO                  76877 non-null  float32
#  21  NAME_EDUCATION_TYPE_Highereducation    76877 non-null  bool
#  22  NAME_FAMILY_STATUS_Married             76877 non-null  bool
#  23  BURO_DAYS_CREDIT_MAX                   65780 non-null  float32
#  24  BURO_DAYS_CREDIT_ENDDATE_MEAN          65221 non-null  float32
#  25  BURO_AMT_CREDIT_SUM_MAX                65780 non-null  float32
#  26  BURO_AMT_CREDIT_SUM_DEBT_MEAN          63933 non-null  float64
#  27  BURO_CREDIT_ACTIVE_Active_MEAN         65780 non-null  float32
#  28  BURO_CREDIT_TYPE_Microloan_MEAN        65780 non-null  float32
#  29  BURO_CREDIT_TYPE_Mortgage_MEAN         65780 non-null  float32
#  30  BURO_STATUS_0_MEAN_MEAN                23110 non-null  float32
#  31  ACTIVE_DAYS_CREDIT_MAX                 54212 non-null  float32
#  32  ACTIVE_DAYS_CREDIT_ENDDATE_MIN         51955 non-null  float32
#  33  ACTIVE_DAYS_CREDIT_ENDDATE_MAX         51955 non-null  float32
#  34  ACTIVE_DAYS_CREDIT_UPDATE_MEAN         54212 non-null  float32
#  35  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN     28839 non-null  float32
#  36  ACTIVE_AMT_CREDIT_SUM_MEAN             54212 non-null  float32
#  37  ACTIVE_AMT_CREDIT_SUM_SUM              54212 non-null  float32
#  38  ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN       47172 non-null  float64
#  39  ACTIVE_MONTHS_BALANCE_SIZE_MEAN        19157 non-null  float32
#  40  CLOSED_DAYS_CREDIT_MAX                 57411 non-null  float32
#  41  CLOSED_DAYS_CREDIT_VAR                 44064 non-null  float32
#  42  CLOSED_DAYS_CREDIT_ENDDATE_MAX         57019 non-null  float32
#  43  CLOSED_DAYS_CREDIT_UPDATE_MEAN         57411 non-null  float32
#  44  CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN     36533 non-null  float32
#  45  CLOSED_AMT_CREDIT_SUM_MEAN             57411 non-null  float32
#  46  CLOSED_AMT_CREDIT_SUM_SUM              57411 non-null  float32
#  47  PREV_AMT_ANNUITY_MIN                   72601 non-null  float32
#  48  PREV_APP_CREDIT_PERC_MAX               63018 non-null  float32
#  49  PREV_AMT_GOODS_PRICE_MIN               72462 non-null  float32
#  50  PREV_HOUR_APPR_PROCESS_START_MAX       72714 non-null  float32
#  51  PREV_DAYS_DECISION_MIN                 72714 non-null  float32
#  52  PREV_DAYS_DECISION_MAX                 72714 non-null  float32
#  53  PREV_CNT_PAYMENT_SUM                   72602 non-null  float32
#  54  PREV_NAME_YIELD_GROUP_low_action_MEAN  72714 non-null  float32
#  55  APPROVED_AMT_ANNUITY_MAX               72446 non-null  float32
#  56  APPROVED_APP_CREDIT_PERC_MIN           72362 non-null  float32
#  57  APPROVED_APP_CREDIT_PERC_MAX           72362 non-null  float32
#  58  APPROVED_AMT_DOWN_PAYMENT_MAX          67768 non-null  float32
#  59  APPROVED_AMT_GOODS_PRICE_MAX           72202 non-null  float32
#  60  APPROVED_DAYS_DECISION_MAX             72447 non-null  float32
#  61  APPROVED_CNT_PAYMENT_MEAN              72447 non-null  float32
#  62  REFUSED_AMT_CREDIT_MIN                 25061 non-null  float32
#  63  REFUSED_APP_CREDIT_PERC_MIN            22944 non-null  float32
#  64  REFUSED_DAYS_DECISION_MAX              25061 non-null  float32
#  65  POS_MONTHS_BALANCE_MEAN                72245 non-null  float32
#  66  POS_SK_DPD_DEF_MEAN                    72245 non-null  float32
#  67  POS_COUNT                              72245 non-null  float32
#  68  INSTAL_DPD_MEAN                        72820 non-null  float32
#  69  INSTAL_DBD_MEAN                        72820 non-null  float32
#  70  INSTAL_DBD_SUM                         72820 non-null  float32
#  71  INSTAL_PAYMENT_PERC_MEAN               72816 non-null  float32
#  72  INSTAL_PAYMENT_PERC_SUM                72816 non-null  float32
#  73  INSTAL_PAYMENT_DIFF_MAX                72820 non-null  float32
#  74  INSTAL_PAYMENT_DIFF_MEAN               72820 non-null  float64
#  75  INSTAL_PAYMENT_DIFF_SUM                72820 non-null  float64
#  76  INSTAL_AMT_INSTALMENT_MAX              72821 non-null  float32
#  77  INSTAL_AMT_INSTALMENT_MEAN             72821 non-null  float32
#  78  INSTAL_AMT_INSTALMENT_SUM              72821 non-null  float32
#  79  INSTAL_AMT_PAYMENT_MIN                 72820 non-null  float32
#  80  INSTAL_DAYS_ENTRY_PAYMENT_MAX          72820 non-null  float32
#  81  INSTAL_DAYS_ENTRY_PAYMENT_SUM          72820 non-null  float64
#  82  CC_AMT_BALANCE_MEAN                    21950 non-null  float32
#  83  CC_AMT_PAYMENT_CURRENT_SUM             15426 non-null  float32
#  84  CC_CNT_DRAWINGS_ATM_CURRENT_MEAN       15441 non-null  float32
#  85  CC_CNT_DRAWINGS_CURRENT_MEAN           21950 non-null  float32
#  86  CC_CNT_DRAWINGS_CURRENT_VAR            21788 non-null  float32
# dtypes: bool(2), float32(76), float64(5), int32(2), int64(2)
# memory usage: 27.7 MB
# Durée de l'évaluation : 0:00:02
# Business gain Train : 0.7457,	Business gain Test : 0.7072

# %%
import matplotlib.pyplot as plt

fig = testor2.plot_conf_mat()
fig

# %% [markdown]
# ## Conclusion des tests

# %%
"""
Les 2 modèles ont des scores corrects sur le test, qui comporte des données jamais vues pendant l'entraînement.
Cela confirme que nous ne sommes pas en surfit (pour les 2 modèles)
"""
